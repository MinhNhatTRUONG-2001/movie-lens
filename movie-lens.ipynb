# %% [markdown]
# # Import packages

# %%
from sqlalchemy import create_engine
from sqlalchemy.sql import text

# %% [markdown]
# # Database connection

# %%
engine = create_engine('sqlite:///movie-lens.db', echo = True)
conn = engine.connect()

# %% [markdown]
# # Test the connection

# %%
num_ratings_query = text('SELECT COUNT(userId) FROM ratings')
num_ratings = conn.execute(num_ratings_query)
print(num_ratings.fetchone()[0])

find_ratings_query = text('SELECT * FROM ratings WHERE userId = 1 AND rating >= 4')
find_ratings = conn.execute(find_ratings_query)
find_ratings.fetchall()
# Out:
# 2025-10-24 00:49:18,976 INFO sqlalchemy.engine.Engine SELECT COUNT(userId) FROM ratings
# 2025-10-24 00:49:18,977 INFO sqlalchemy.engine.Engine [cached since 12.11s ago] ()
# 100836
# 2025-10-24 00:49:18,992 INFO sqlalchemy.engine.Engine SELECT * FROM ratings WHERE userId = 1 AND rating >= 4
# 2025-10-24 00:49:18,993 INFO sqlalchemy.engine.Engine [cached since 12.11s ago] ()
# [(1, 1, 4.0, 964982703),
#  (1, 3, 4.0, 964981247),
#  (1, 6, 4.0, 964982224),
#  (1, 47, 5.0, 964983815),
#  (1, 50, 5.0, 964982931),
#  (1, 101, 5.0, 964980868),
#  (1, 110, 4.0, 964982176),
#  (1, 151, 5.0, 964984041),
#  (1, 157, 5.0, 964984100),
#  (1, 163, 5.0, 964983650),
#  (1, 216, 5.0, 964981208),
#  (1, 231, 5.0, 964981179),
#  (1, 235, 4.0, 964980908),
#  (1, 260, 5.0, 964981680),
#  (1, 333, 5.0, 964981179),
#  (1, 349, 4.0, 964982563),
#  (1, 356, 4.0, 964980962),
#  (1, 362, 5.0, 964982588),
#  (1, 367, 4.0, 964981710),
#  (1, 441, 4.0, 964980868),
#  (1, 457, 5.0, 964981909),
# ...

# %% [markdown]
# # Close the connection

# %%
conn.close()
# Out:
# 2025-10-24 00:49:39,464 INFO sqlalchemy.engine.Engine ROLLBACK
