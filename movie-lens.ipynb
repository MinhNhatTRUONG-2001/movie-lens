# %% [markdown]
# # Import packages

# %%
from sqlalchemy import create_engine
from sqlalchemy.sql import text
import numpy as np

# %% [markdown]
# # Database connection

# %%
engine = create_engine('sqlite:///movie-lens.db', echo = True)
conn = engine.connect()

# %% [markdown]
# # User-based collaborative filtering using the Pearson correlation function

# %%
def calculate_similarities(user_a_id):
    # Get mean rating of user a
    user_a_mean_rating_query = text(f'SELECT AVG(rating) FROM ratings WHERE userId = {user_a_id}')
    user_a_mean_rating_result = conn.execute(user_a_mean_rating_query)
    user_a_mean_rating = user_a_mean_rating_result.fetchone()[0]
    # Get all other user b IDs who are in 'ratings' table
    user_b_ids_query = text(f'SELECT DISTINCT userId FROM ratings WHERE userId != {user_a_id}')
    user_b_ids_result = conn.execute(user_b_ids_query)
    user_b_ids = np.array(user_b_ids_result.fetchall()).transpose()[0]
    similarities = [] # Similarity between the user a and every user b
    for user_b_id in user_b_ids:
        # Get rating of user a and user b for each movie which is rated by both users
        both_users_ratings_each_movie_query = text(f'SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = {user_a_id} AND r2.userId = {user_b_id} AND r1.movieId = r2.movieId')
        both_users_ratings_each_movie_result = conn.execute(both_users_ratings_each_movie_query)
        both_users_ratings_each_movie = both_users_ratings_each_movie_result.fetchall()
        if both_users_ratings_each_movie.__len__() == 0:
            continue
        _ , _, user_a_rating_list, _, user_b_rating_list = zip(*both_users_ratings_each_movie)
        user_a_rating_list = np.array(user_a_rating_list)
        user_b_rating_list = np.array(user_b_rating_list)
        # Get mean rating of user b
        user_b_mean_rating_query = text(f'SELECT AVG(rating) FROM ratings WHERE userId = {user_b_id}')
        user_b_mean_rating_result = conn.execute(user_b_mean_rating_query)
        user_b_mean_rating = user_b_mean_rating_result.fetchone()[0]
        # Calculate similarity between user a and b
        numerator = np.sum(np.multiply(user_a_rating_list - user_a_mean_rating, user_b_rating_list - user_b_mean_rating))
        denominator = np.sqrt(np.sum(np.multiply(user_a_rating_list - user_a_mean_rating, user_a_rating_list - user_a_mean_rating))) * np.sqrt(np.sum(np.multiply(user_b_rating_list - user_b_mean_rating, user_b_rating_list - user_b_mean_rating)))
        sim_a_b = numerator / denominator
        similarities.append([user_b_id, sim_a_b])
    similarities.sort(key=lambda sim: sim[1], reverse=True) # Sort by similarity values, descending
    return similarities

# %%
sim_list = calculate_similarities(1)
sim_list
# Out:
# 2025-10-25 19:37:32,665 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 1
# 2025-10-25 19:37:32,668 INFO sqlalchemy.engine.Engine [cached since 2562s ago] ()
# 2025-10-25 19:37:32,679 INFO sqlalchemy.engine.Engine SELECT DISTINCT userId FROM ratings WHERE userId != 1
# 2025-10-25 19:37:32,680 INFO sqlalchemy.engine.Engine [cached since 1.125e+04s ago] ()
# 2025-10-25 19:37:32,703 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 2 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:32,703 INFO sqlalchemy.engine.Engine [cached since 9693s ago] ()
# 2025-10-25 19:37:32,728 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 2
# 2025-10-25 19:37:32,728 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:32,737 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 3 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:32,737 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:32,760 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 3
# 2025-10-25 19:37:32,760 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:32,774 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 4 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:32,774 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:32,796 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 4
# 2025-10-25 19:37:32,796 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:32,810 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 5 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:32,811 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:32,830 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 5
# 2025-10-25 19:37:32,830 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:32,845 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 6 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:32,845 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:32,869 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 6
# 2025-10-25 19:37:32,870 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:32,881 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 7 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:32,881 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:32,905 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 7
# 2025-10-25 19:37:32,909 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:32,920 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 8 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:32,921 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:32,943 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 8
# 2025-10-25 19:37:32,944 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:32,956 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 9 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:32,957 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:32,978 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 9
# 2025-10-25 19:37:32,979 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:32,993 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 10 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:32,994 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,016 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 10
# 2025-10-25 19:37:33,017 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,028 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 11 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,028 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,049 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 11
# 2025-10-25 19:37:33,050 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,061 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 12 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,063 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,084 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 12
# 2025-10-25 19:37:33,085 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,097 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 13 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,097 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,119 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 13
# 2025-10-25 19:37:33,120 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,130 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 14 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,131 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,153 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 14
# 2025-10-25 19:37:33,154 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,165 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 15 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,166 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,186 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 15
# 2025-10-25 19:37:33,186 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,196 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 16 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,201 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,220 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 16
# 2025-10-25 19:37:33,220 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,234 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 17 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,235 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,253 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 17
# 2025-10-25 19:37:33,253 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,269 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 18 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,269 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,290 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 18
# 2025-10-25 19:37:33,292 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,304 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 19 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,304 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,327 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 19
# 2025-10-25 19:37:33,327 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,338 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 20 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,341 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,363 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 20
# 2025-10-25 19:37:33,363 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,375 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 21 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,376 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,396 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 21
# 2025-10-25 19:37:33,396 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,410 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 22 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,410 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,429 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 22
# 2025-10-25 19:37:33,429 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,444 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 23 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,444 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,466 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 23
# 2025-10-25 19:37:33,466 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,478 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 24 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,479 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,500 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 24
# 2025-10-25 19:37:33,501 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,512 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 25 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,513 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,533 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 25
# 2025-10-25 19:37:33,534 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,546 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 26 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,546 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,568 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 26
# 2025-10-25 19:37:33,569 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,579 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 27 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,581 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,602 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 27
# 2025-10-25 19:37:33,603 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,614 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 28 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,615 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,635 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 28
# 2025-10-25 19:37:33,636 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,646 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 29 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,646 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,670 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 29
# 2025-10-25 19:37:33,670 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,681 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 30 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,683 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,703 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 30
# 2025-10-25 19:37:33,704 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,716 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 31 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,718 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,741 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 31
# 2025-10-25 19:37:33,743 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,754 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 32 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,754 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,777 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 32
# 2025-10-25 19:37:33,777 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,788 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 33 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,790 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,811 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 33
# 2025-10-25 19:37:33,812 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,823 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 34 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,824 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,846 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 34
# 2025-10-25 19:37:33,846 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,858 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 35 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,858 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,879 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 35
# 2025-10-25 19:37:33,880 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,892 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 36 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,893 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,914 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 36
# 2025-10-25 19:37:33,914 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,926 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 37 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,926 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,948 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 37
# 2025-10-25 19:37:33,948 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,960 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 38 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,960 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:33,980 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 38
# 2025-10-25 19:37:33,980 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:33,993 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 39 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:33,993 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,015 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 39
# 2025-10-25 19:37:34,015 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,027 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 40 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,027 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,047 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 40
# 2025-10-25 19:37:34,049 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,061 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 41 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,063 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,080 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 41
# 2025-10-25 19:37:34,084 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,096 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 42 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,096 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,118 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 42
# 2025-10-25 19:37:34,119 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,129 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 43 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,131 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,151 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 43
# 2025-10-25 19:37:34,152 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,163 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 44 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,163 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,186 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 44
# 2025-10-25 19:37:34,186 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,198 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 45 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,198 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,221 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 45
# 2025-10-25 19:37:34,221 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,232 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 46 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,233 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,254 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 46
# 2025-10-25 19:37:34,255 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,267 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 47 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,267 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,288 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 47
# 2025-10-25 19:37:34,289 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,300 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 48 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,300 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,321 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 48
# 2025-10-25 19:37:34,321 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,333 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 49 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,334 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,354 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 49
# 2025-10-25 19:37:34,355 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,366 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 50 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,367 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,388 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 50
# 2025-10-25 19:37:34,390 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,402 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 51 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,403 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,425 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 51
# 2025-10-25 19:37:34,425 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,436 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 52 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,437 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,459 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 52
# 2025-10-25 19:37:34,460 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,472 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 53 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,472 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,494 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 53
# 2025-10-25 19:37:34,494 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,505 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 54 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,506 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,528 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 54
# 2025-10-25 19:37:34,529 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,540 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 55 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,540 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,561 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 55
# 2025-10-25 19:37:34,562 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,573 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 56 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,574 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,596 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 56
# 2025-10-25 19:37:34,596 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,607 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 57 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,607 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,629 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 57
# 2025-10-25 19:37:34,629 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,639 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 58 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,643 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,662 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 58
# 2025-10-25 19:37:34,662 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,676 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 59 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,677 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,697 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 59
# C:\Users\minhn\AppData\Local\Temp\ipykernel_1460\1899846935.py:28: RuntimeWarning: invalid value encountered in scalar divide
#   sim_a_b = numerator / denominator
# 2025-10-25 19:37:34,697 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,710 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 60 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,710 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,736 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 60
# 2025-10-25 19:37:34,736 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,747 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 61 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,747 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,770 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 61
# 2025-10-25 19:37:34,771 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,783 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 62 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,783 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,806 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 62
# 2025-10-25 19:37:34,806 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,819 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 63 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,820 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,840 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 63
# 2025-10-25 19:37:34,840 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,854 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 64 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,854 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,876 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 64
# 2025-10-25 19:37:34,877 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,889 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 65 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,889 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,910 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 65
# 2025-10-25 19:37:34,911 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,922 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 66 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,922 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,945 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 66
# 2025-10-25 19:37:34,946 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,955 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 67 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,955 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:34,979 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 67
# 2025-10-25 19:37:34,979 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:34,989 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 68 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:34,989 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,013 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 68
# 2025-10-25 19:37:35,013 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,023 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 69 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,026 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,053 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 69
# 2025-10-25 19:37:35,054 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,066 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 70 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,067 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,089 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 70
# 2025-10-25 19:37:35,089 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,101 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 71 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,102 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,124 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 71
# 2025-10-25 19:37:35,124 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,136 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 72 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,137 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,159 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 72
# 2025-10-25 19:37:35,159 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,171 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 73 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,171 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,194 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 73
# 2025-10-25 19:37:35,195 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,207 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 74 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,208 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,231 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 74
# 2025-10-25 19:37:35,231 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,244 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 75 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,244 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,265 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 75
# 2025-10-25 19:37:35,266 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,278 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 76 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,279 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,301 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 76
# 2025-10-25 19:37:35,301 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,312 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 77 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,314 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,334 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 77
# 2025-10-25 19:37:35,334 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,346 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 78 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,347 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,368 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 78
# 2025-10-25 19:37:35,369 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,379 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 79 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,379 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,401 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 79
# 2025-10-25 19:37:35,402 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,414 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 80 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,414 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,435 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 80
# 2025-10-25 19:37:35,435 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,447 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 81 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,447 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,467 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 81
# 2025-10-25 19:37:35,468 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,479 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 82 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,480 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,502 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 82
# 2025-10-25 19:37:35,502 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,514 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 83 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,515 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,535 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 83
# 2025-10-25 19:37:35,536 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,547 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 84 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,548 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,567 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 84
# 2025-10-25 19:37:35,568 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,581 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 85 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,581 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,601 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 85
# 2025-10-25 19:37:35,602 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,613 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 86 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,613 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,629 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 86
# 2025-10-25 19:37:35,629 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,645 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 87 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,645 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,662 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 87
# 2025-10-25 19:37:35,662 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,675 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 88 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,677 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,696 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 88
# 2025-10-25 19:37:35,696 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,709 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 89 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,709 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,729 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 89
# 2025-10-25 19:37:35,730 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,743 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 90 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,743 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,769 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 90
# 2025-10-25 19:37:35,771 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,783 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 91 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,784 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,804 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 91
# 2025-10-25 19:37:35,805 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,817 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 92 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,817 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,837 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 92
# 2025-10-25 19:37:35,837 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,849 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 93 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,849 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,869 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 93
# 2025-10-25 19:37:35,870 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,881 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 94 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,882 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,902 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 94
# 2025-10-25 19:37:35,902 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,913 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 95 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,913 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,934 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 95
# 2025-10-25 19:37:35,934 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,946 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 96 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,947 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:35,962 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 96
# 2025-10-25 19:37:35,968 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:35,979 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 97 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:35,979 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:36,000 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 97
# 2025-10-25 19:37:36,001 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:36,012 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 98 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:36,012 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:36,029 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 98
# 2025-10-25 19:37:36,029 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:36,045 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 99 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:36,045 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# 2025-10-25 19:37:36,065 INFO sqlalchemy.engine.Engine SELECT AVG(rating) FROM ratings WHERE userId = 99
# 2025-10-25 19:37:36,066 INFO sqlalchemy.engine.Engine [cached since 414.3s ago] ()
# 2025-10-25 19:37:36,079 INFO sqlalchemy.engine.Engine SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = 1 AND r2.userId = 100 AND r1.movieId = r2.movieId
# 2025-10-25 19:37:36,079 INFO sqlalchemy.engine.Engine [cached since 247.8s ago] ()
# ...
#  [72, 0.5798547717605266],
#  [494, 0.5772849193621854],
#  [236, 0.5680348832136561],
#  [596, 0.5626528403219744],
#  [595, 0.5588814721805508],
#  [178, 0.5427107863446915],
#  [301, 0.5426370552515191],
#  [479, 0.540738895771055],
#  [360, 0.5372608625699853],
#  [450, 0.5368200782385798],
#  [516, 0.5261754701664372],
#  [20, 0.5256863271011928],
#  [120, 0.5228781610344042],
#  [113, 0.5152989716673757],
#  [300, 0.51512964126458],
#  [209, 0.5090743087666184],
#  [442, 0.5004253976674229],
#  [248, 0.4950088227964896],
#  [593, 0.4945730604994912],
#  [172, 0.4938977724245948],
#  [484, 0.4794592242155359],
#  [319, 0.47472005794679906],
#  [204, 0.46966007943332716],
#  [112, 0.4686607964394024],
#  [185, 0.4627415563822943],
#  [513, 0.4610302416479067],
#  [259, 0.4594229188737669],
#  [215, 0.4568993230506795],
#  [508, 0.4481574090417329],
#  [582, 0.44763450156082935],
#  [597, 0.44398472080306917],
#  [173, 0.4403531571684635],
#  [263, 0.4374051622408375],
#  [392, 0.435688213767504],
#  [526, 0.4339539215220165],
#  [351, 0.42893659631389514],
#  [394, 0.42865651102967717],
#  [476, 0.42724318835459085],
#  [8, 0.4265612329426459],
#  [531, 0.4222969111535679],
#  [449, 0.4188588741538516],
#  [299, 0.41704982260385454],
#  [75, 0.4155404132343472],
#  [302, 0.4137174090392173],
#  [163, 0.4125045828295921],
#  [418, 0.4117654146199716],
#  [477, 0.40039046185027416],
#  [214, 0.39722071559455696],
#  [344, 0.3945162399411957],
#  [76, 0.3934156029081488],
#  [574, 0.38994435044075904],
#  [464, 0.3886430134982348],
#  [414, 0.3875690218608711],
#  [266, 0.3866800634844441],
#  [316, 0.38466230392043443],
#  [124, 0.3803765933942927],
#  [524, 0.3797542908833763],
#  [552, 0.37938748992592614],
#  [167, 0.3773172223006228],
#  [99, 0.37497812484999915],
#  [495, 0.3724342758773573],
#  [435, 0.3723577446318008],
#  [563, 0.3698242309926496],
#  [165, 0.36881750340237474],
#  [122, 0.3661910324812392],
#  [198, 0.36533142230644955],
#  [136, 0.3631262161748454],
#  [123, 0.36232915272265565],
#  [327, 0.36227199220339024],
#  [326, 0.3590922307137231],
#  [523, 0.3586359643598666],
#  [110, 0.35640335848524857],
#  [9, 0.35473856827532246],
#  [176, 0.35168111009808384],
#  [199, 0.3508011334731448],
#  [312, 0.3483179698002844],
#  [201, 0.348227002438596],
#  [168, 0.3464844430744409],
#  [434, 0.3403245273639118],
#  [226, 0.33860888878360673],
#  [211, 0.336255183608093],
#  [451, 0.3357902552328431],
#  [101, 0.3349283393651672],
#  [95, 0.3342597220343572],
#  [307, 0.3301056288962978],
#  [171, 0.3286180916079159],
#  [222, 0.3256238828188242],
#  [116, 0.32405875013470703],
#  [540, 0.32271307912123937],
#  [504, 0.32246879906317094],
#  [350, 0.32186094441494817],
#  [133, 0.3216528029669139],
#  [254, 0.3197989682020866],
#  [126, 0.31737418711582827],
#  [255, 0.31722421111944915],
#  [543, 0.31555612503068126],
#  [590, 0.3152580660984529],
#  [268, 0.3149702070774206],
#  [577, 0.3131258558211115],
#  [399, 0.31275935978915725],
#  [196, 0.312746669775567],
#  [15, 0.31204846354219923],
#  [601, 0.3091898361871768],
#  [572, 0.3091842224671573],
#  [481, 0.3077488189129732],
#  [160, 0.30708974170151254],
#  [545, 0.30434249912771033],
#  [135, 0.3038623028000204],
#  [125, 0.30221335068180744],
#  [483, 0.30183776990200517],
#  [488, 0.3013105346080467],
#  [408, 0.2957690297420316],
#  [507, 0.2928740162922903],
#  [469, 0.2872561277960428],
#  [314, 0.28669495787298854],
#  [555, 0.28515741965599367],
#  [422, 0.2847543592990932],
#  [387, 0.2771217021895059],
#  [498, 0.2768915745175199],
#  [510, 0.27652062247880227],
#  [272, 0.27155085656522826],
#  [32, 0.2700743905723179],
#  [287, 0.2699075437050527],
#  [323, 0.26929265282992737],
#  [310, 0.26796248399089406],
#  [348, 0.2678276023692942],
#  [115, 0.26549773994142617],
#  [608, 0.2645867419113092],
#  [448, 0.2645215462813272],
#  [512, 0.26447373410095093],
#  [328, 0.26446617796527344],
#  [600, 0.26138281261951557],
#  [189, 0.2606632287576406],
#  [385, 0.2597906033519064],
#  [519, 0.2581809797905106],
#  [249, 0.2577051946190732],
#  [332, 0.2554013863370365],
#  [212, 0.253491191309409],
#  [219, 0.2527314562101387],
#  [88, 0.25240651646280843],
#  [542, 0.2518436499332252],
#  [169, 0.25061646500949125],
#  [200, 0.2505594651176311],
#  [298, 0.2488815880162929],
#  [352, 0.24200387110534516],
#  [239, 0.24197359734042992],
#  [322, 0.24129573522262016],
#  [86, 0.23496912233034697],
#  [415, 0.23327340239303923],
#  [73, 0.23218937610784088],
#  [480, 0.23155023077901063],
#  [262, 0.23113498204168278],
#  [18, 0.23106109729152335],
#  [355, 0.23078811248320494],
#  [341, 0.22979468007270626],
#  [371, 0.22908623272320153],
#  [205, 0.22827442904465656],
#  [561, 0.22674456174618354],
#  [19, 0.22574845026891868],
#  [14, 0.2253535048415333],
#  [303, 0.22501982206919932],
#  [107, 0.22032423593505485],
#  [216, 0.21804167133936642],
#  [292, 0.2179923264344002],
#  [246, 0.2155225407576923],
#  [223, 0.21399536466149008],
#  [80, 0.21182921004177932],
#  [591, 0.21059489418342217],
#  [4, 0.2104232878167512],
#  [432, 0.20985862397583493],
#  [514, 0.20890073323064343],
#  [155, 0.20465702122436485],
#  [251, 0.20270676655796732],
#  [187, 0.20176969494805244],
#  [296, 0.1989877102538233],
#  [17, 0.1984417997849796],
#  [159, 0.19837186551000405],
#  [288, 0.19683503193291907],
#  [233, 0.1966783232729462],
#  [265, 0.19625098355007123],
#  [336, 0.19562047199479465],
#  [144, 0.19545135218853266],
#  [5, 0.19472139278694267],
#  [391, 0.18976059657085823],
#  [368, 0.1885128117814459],
#  [457, 0.18739773848609761],
#  [78, 0.18685193761617874],
#  [420, 0.18631132298368513],
#  [130, 0.18620928747446563],
#  [502, 0.18502412782205307],
#  [182, 0.18154353615453064],
#  [27, 0.18060517781572202],
#  [339, 0.17643912685274363],
#  [607, 0.175701726657881],
#  [244, 0.17473311166270525],
#  [379, 0.1739840075575859],
#  [267, 0.17252020461897616],
#  [599, 0.1680221382957355],
#  [286, 0.1663790762279706],
#  [170, 0.1657254586088685],
#  [503, 0.16548748818049508],
#  [208, 0.16514948285041656],
#  [145, 0.16489061325732188],
#  [111, 0.16372691276235446],
#  [213, 0.16361493838517688],
#  [581, 0.16354147221478596],
#  [447, 0.15935462035093076],
#  [533, 0.15588231439778394],
#  [570, 0.1536325330342541],
#  [106, 0.15332539001755377],
#  [536, 0.15316086420536895],
#  [530, 0.15282286009174648],
#  [100, 0.15167860704772695],
#  [558, 0.15127844419813627],
#  [343, 0.14937397884790907],
#  [490, 0.14809344373157943],
#  [400, 0.14742928984841083],
#  [247, 0.14738377174794928],
#  [412, 0.14695849382375753],
#  [598, 0.14694556651418378],
#  [493, 0.14613315398344343],
#  [458, 0.14469346461112628],
#  [220, 0.14328853147638582],
#  [232, 0.1422693006722428],
#  [108, 0.14167442150658643],
#  [304, 0.14137722194240052],
#  [436, 0.1409984965972281],
#  [428, 0.14039357256056734],
#  [83, 0.13857426574529005],
#  [261, 0.13780386379532852],
#  [166, 0.13764252230084348],
#  [474, 0.13582316047883472],
#  [330, 0.13538744981475653],
#  [489, 0.13448404516775647],
#  [460, 0.13268852710929308],
#  [381, 0.12599159962723658],
#  [560, 0.12426374592847785],
#  [509, 0.12384617119153708],
#  [103, 0.1237103197338458],
#  [453, 0.12312361165637774],
#  [393, 0.12203386910755586],
#  [356, 0.12088518423532825],
#  [338, 0.11942008080967711],
#  [177, 0.11537165970317628],
#  [190, 0.11065666703449747],
#  [585, 0.107511460402867],
#  [357, 0.10648289305851188],
#  [475, 0.10556705914466889],
#  [33, 0.10531918357689701],
#  [96, 0.10052897284908388],
#  [525, 0.10036731017386208],
#  [117, 0.10020659522953095],
#  [309, 0.10007595578228785],
#  [580, 0.09987147923806301],
#  [153, 0.09904216259647991],
#  [586, 0.09873244969484686],
#  [610, 0.09686989769878454],
#  [455, 0.09636581194963091],
#  [517, 0.09629829643930989],
#  [118, 0.09580378808202378],
#  [137, 0.09527590757249839],
#  [192, 0.09477547593857909],
#  [275, 0.09274647063281904],
#  [407, 0.0901438013815581],
#  [410, 0.08946262849924014],
#  [429, 0.08849268272693923],
#  [359, 0.08793869455534689],
#  [290, 0.08654357303540117],
#  [21, 0.08648178161396773],
#  [308, 0.08511316064195729],
#  [82, 0.0843164569160052],
#  [522, 0.08306647242487986],
#  [276, 0.08303503870467581],
#  [234, 0.08191486320638905],
#  [119, 0.0818674750632834],
#  [380, 0.08109378855149191],
#  [365, 0.08043297338458477],
#  [311, 0.07840117965451804],
#  [382, 0.07750228377175684],
#  [202, 0.07593593389513187],
#  [515, 0.07495137642781906],
#  [282, 0.07419998476654148],
#  [568, 0.07404189955274608],
#  [305, 0.07348582232367704],
#  [221, 0.0717302423121202],
#  [91, 0.07104333159030912],
#  [419, 0.07079829565272398],
#  [606, 0.07043315894376881],
#  [274, 0.07031776565830783],
#  [439, 0.07022010283529262],
#  [105, 0.06931106357794137],
#  [228, 0.06714223133808939],
#  [538, 0.066057825907582],
#  [573, 0.06466433809953546],
#  [140, 0.06466252016925829],
#  [242, 0.06158360163700135],
#  [132, 0.06125034952695561],
#  [237, 0.06001820162527472],
#  [313, 0.0590146494892009],
#  [554, 0.05528839845006513],
#  [225, 0.054764071433540396],
#  [31, 0.0524049522319235],
#  [30, 0.05197519878093253],
#  [24, 0.05176459800704183],
#  [283, 0.05126638418965349],
#  [468, 0.050841180567491547],
#  [16, 0.049634084292101116],
#  [438, 0.048328989656679276],
#  [425, 0.048303366438385474],
#  [520, 0.04793597191279806],
#  [87, 0.04756514941544918],
#  [270, 0.04677084313378575],
#  [260, 0.046231315731662496],
#  [152, 0.043165193533020174],
#  [409, 0.04311469631977923],
#  [331, 0.03815781356610167],
#  [532, 0.03661972061374968],
#  [452, 0.03612415179891862],
#  [141, 0.03536817067355413],
#  [131, 0.03526656583262371],
#  [104, 0.03333633112137358],
#  [386, 0.03319140165027113],
#  [364, 0.03256612806864234],
#  [562, 0.025515321009913574],
#  [256, 0.022328522206736177],
#  [335, 0.02024035033021008],
#  [342, 0.01971825196820393],
#  [97, 0.018616023406967698],
#  [25, 0.018122806444241503],
#  [188, 0.017514446445095165],
#  [565, 0.016501686665372908],
#  [218, 0.016245213450703448],
#  [575, 0.012741649320810755],
#  [3, 0.011225168459991653],
#  [527, 0.011106462741122395],
#  [191, 0.009875658351489283],
#  [28, 0.009072639414787094],
#  [354, 0.008855986524654195],
#  [325, 0.008689695611768538],
#  [156, 0.0072388451903199905],
#  [193, 0.0053330454791332485],
#  [546, 0.004369925874231617],
#  [567, 0.0029854795425866562],
#  [497, 0.0028906788270262433],
#  [551, 0.0011960539370450196],
#  [396, 0.0007438997177310088],
#  [93, -0.0025830401279538164],
#  [576, -0.003013045551481692],
#  [437, -0.00820298371448198],
#  [372, -0.008353181447005505],
#  [471, -0.008420735190454196],
#  [534, -0.011601786086292401],
#  [186, -0.014497571633988187],
#  [318, -0.01478282103247465],
#  [528, -0.018136951102016404],
#  [279, -0.01944903213716526],
#  [142, -0.022046823167970107],
#  [403, -0.026259681530658715],
#  [294, -0.028040772179793717],
#  [334, -0.03029801862828245],
#  [378, -0.03238376820558866],
#  [138, -0.033101007820618054],
#  [217, -0.03862994560295979],
#  [84, -0.0415253604997883],
#  [462, -0.0444261990317554],
#  [500, -0.04488821976776685],
#  [7, -0.046641563830548446],
#  [340, -0.04771497671156997],
#  [443, -0.047839289106356556],
#  [151, -0.05325556835390905],
#  [281, -0.05594542388644607],
#  [470, -0.05629023223299863],
#  [195, -0.059850574872933306],
#  [320, -0.06112274566280436],
#  [603, -0.06182787312059786],
#  [29, -0.06324805671604673],
#  [280, -0.06524045367935197],
#  [74, -0.07061419924751659],
#  [374, -0.07212092492196305],
#  [227, -0.07227114827760543],
#  [129, -0.07684915006818603],
#  [454, -0.07746555613616551],
#  [231, -0.07872696365978649],
#  [406, -0.08017891146156206],
#  [594, -0.08403679786880534],
#  [544, -0.08632753423472007],
#  [79, -0.08640786530899863],
#  [362, -0.08656276254196761],
#  [465, -0.09378605776798968],
#  [424, -0.0968305173908086],
#  [588, -0.10059940530131177],
#  [602, -0.1039605364862371],
#  [109, -0.10555219587402531],
#  [584, -0.10600668423345365],
#  [521, -0.11542984717471384],
#  [181, -0.12194434493399553],
#  [240, -0.12409994922194859],
#  [22, -0.1302706228212957],
#  [559, -0.13308892151558785],
#  [347, -0.1344126498561293],
#  [373, -0.13524018639091243],
#  [264, -0.1390622161219786],
#  [547, -0.14142135623730986],
#  [353, -0.14166037532539943],
#  [444, -0.146491948859333],
#  [539, -0.14747999474756682],
#  [26, -0.14770835432617932],
#  [317, -0.1495015566702266],
#  [404, -0.1500616363048761],
#  [10, -0.15121755406386428],
#  [269, -0.15225971745481867],
#  [197, -0.1527045839734087],
#  [149, -0.1529157646445841],
#  [405, -0.15329286055377753],
#  [128, -0.15538720669463196],
#  [271, -0.15879251371839992],
#  [456, -0.15965081883184926],
#  [441, -0.16017004469924537],
#  [605, -0.16165127544524238],
#  [293, -0.16180621530723988],
#  [583, -0.1647900395099868],
#  [367, -0.16925377600629807],
#  [416, -0.16958164176538004],
#  [143, -0.1723476145813544],
#  [273, -0.17547360693950023],
#  [566, -0.18105756787701113],
#  [194, -0.18162144368640784],
#  [289, -0.1827408402992552],
#  [390, -0.18473330414845532],
#  [238, -0.1907370965149668],
#  [250, -0.19208242100119924],
#  [295, -0.19261205570769377],
#  [376, -0.19498623581110014],
#  [417, -0.20549831186463857],
#  [389, -0.2102752150448177],
#  [446, -0.21149606248476546],
#  [277, -0.21178221929157676],
#  [229, -0.21194190153646808],
#  [485, -0.21259093647072036],
#  [529, -0.21537360491394722],
#  [377, -0.22194677582165406],
#  [384, -0.2220149721557375],
#  [564, -0.22525908563703867],
#  [179, -0.22941541651385455],
#  [164, -0.22988728650114318],
#  [349, -0.23175033554644198],
#  [81, -0.23320601710818084],
#  [183, -0.23852722373017732],
#  [413, -0.25064838026288155],
#  [235, -0.2534240333405536],
#  [241, -0.2559958769256044],
#  [433, -0.2587557940163539],
#  [23, -0.26068498223507336],
#  [346, -0.273440180781638],
#  [230, -0.27879813829370126],
#  [609, -0.28680854950312257],
#  [557, -0.28941741448460456],
#  [174, -0.290232187509599],
#  [6, -0.3020187823310266],
#  [571, -0.3129651087813456],
#  [587, -0.3132292878734975],
#  [553, -0.3146152861867036],
#  [361, -0.32663877046987444],
#  [134, -0.3321593098401097],
#  [345, -0.3370231635116701],
#  [541, -0.3419666345249408],
#  [423, -0.3451071961803226],
#  [370, -0.3567911801284778],
#  [89, -0.359240290595222],
#  [427, -0.36019611732336204],
#  [482, -0.3647208446114935],
#  [463, -0.36556882276138375],
#  [569, -0.3724995654248492],
#  [549, -0.3748423411664829],
#  [518, -0.3854240912160685],
#  [411, -0.3876266951175184],
#  [337, -0.3886819344805243],
#  [592, -0.39886920357029415],
#  [321, -0.39991087177467666],
#  [147, -0.4017336838570992],
#  [92, -0.4019102681402828],
#  [426, -0.4022595795435],
#  [363, -0.4092004966394826],
#  [121, -0.41095662792849263],
#  [224, -0.4186960554138277],
#  [537, -0.4216524067531732],
#  [329, -0.42287660146025596],
#  [461, -0.4312808227846005],
#  [257, -0.4343412923126343],
#  [579, -0.4354218579195247],
#  [102, -0.44054124499520997],
#  [11, -0.4499572307079907],
#  [53, nan],
#  [65, 0.8235706673737208],
#  [49, 0.7526685694780164],
#  [44, 0.608688341760208],
#  [47, 0.5190549613113596],
#  [62, 0.509486184626367],
#  [36, 0.44197925638731167],
#  [55, 0.3699247939974139],
#  [60, 0.35985608634244054],
#  [57, 0.352989569707511],
#  [35, 0.31319277272972756],
#  [63, 0.31043945648763177],
#  [69, 0.259320999946202],
#  [58, 0.2555807078269465],
#  [45, 0.23925223511211766],
#  [64, 0.19896419763139409],
#  [61, 0.18812419460171584],
#  [43, 0.15127433370017648],
#  [42, 0.14466533479418028],
#  [66, 0.14171645629119986],
#  [56, 0.12800019089988351],
#  [34, 0.1000962747953274],
#  [51, 0.06750473469150883],
#  [38, 0.058071462757481596],
#  [59, 0.056828898688171925],
#  [68, 0.027260275613023747],
#  [50, 0.0042898782337587905],
#  [46, -0.01650020394955157],
#  [70, -0.11293594492386792],
#  [41, -0.14275873308542525],
#  [48, -0.15531936895347823],
#  [54, -0.18897310978167356],
#  [67, -0.19364572132541757],
#  [39, -0.2254567309877416],
#  [40, -0.3552245041463019],
#  [52, -0.35884674802069716],
#  [37, -0.4190433919782271],
#  [492, -0.4534923928029357],
#  [589, -0.45419848441686683],
#  [284, -0.4545877784142398],
#  [604, -0.46314703333158513],
#  [94, -0.4674464426061038],
#  [486, -0.4714917736404597],
#  [150, -0.48704461727388826],
#  [402, -0.49034229245838645],
#  [395, -0.5017325864505102],
#  [548, -0.5073839869239473],
#  [285, -0.5311459905036076],
#  [466, -0.5521424885746613],
#  [98, -0.5631972799282221],
#  [203, -0.6022329993111621],
#  [243, -0.6137110517341314],
#  [161, -0.6514725648623063],
#  [71, -0.7325721416951918],
#  [491, -0.7354269138333143],
#  [501, -0.8376530667911729],
#  [252, -0.8661138397636851],
#  [158, -0.8706197627477436],
#  [459, -0.908621700848509],
#  [148, -0.982806583276678],
#  [440, -0.9974431591495976],
#  [184, -1.0],
#  [245, -1.0],
#  [315, -1.0],
#  [383, -1.0]]

# %% [markdown]
# # Close the connection

# %%
conn.close()
# Out:
# 2025-10-25 19:40:21,872 INFO sqlalchemy.engine.Engine ROLLBACK
