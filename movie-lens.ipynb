# %% [markdown]
# # Import packages

# %%
from sqlalchemy import create_engine
from sqlalchemy.sql import text
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict

# %% [markdown]
# # Database connection

# %%
engine = create_engine('sqlite:///movie-lens.db', echo = False)
conn = engine.connect()

# %% [markdown]
# # Part 1: User-based collaborative filtering & Group recommendation

# %%
# Group of user IDs
group = [67, 80, 179, 286, 545]

# %% [markdown]
# ## Option 1: Pearson correlation function

# %% [markdown]
# ### Calculate similarities for every user in the group using the Pearson correlation function

# %%
# Calculate similarities between user a and every other user b
# and return all user b whose similarity to user a is larger than the threshhold
def calculate_similarities(user_a_id, threshold = 0.5):
    # Get mean rating of user a
    user_a_mean_rating_query = text(f'SELECT AVG(rating) FROM ratings WHERE userId = {user_a_id}')
    user_a_mean_rating_result = conn.execute(user_a_mean_rating_query)
    user_a_mean_rating = user_a_mean_rating_result.fetchone()[0]

    # Get all other user b mean ratings and all movie ratings
    user_b_mean_ratings_query = text(f'SELECT userId, AVG(rating) FROM ratings WHERE userId != {user_a_id} GROUP BY userId')
    user_b_mean_ratings_result = conn.execute(user_b_mean_ratings_query)
    user_b_mean_ratings = user_b_mean_ratings_result.fetchall()

    # Get movies rated by both user a and each user b
    both_users_ratings_each_movie_query = text(f"""
        SELECT 
            r1.movieId,
            r1.userId AS user_a_id,
            r1.rating AS user_a_rating,
            r2.userId AS user_b_id,
            r2.rating AS user_b_rating
        FROM ratings r1
        JOIN ratings r2 ON r1.movieId = r2.movieId
        WHERE r1.userId = {user_a_id}
    """)
    both_users_ratings_each_movie_df = pd.read_sql(both_users_ratings_each_movie_query, conn)

    similarities = [] # Similarity between the user a and every user b

    for user_b_id, user_b_mean_rating in user_b_mean_ratings:
        # Filter movies rated by both user a and current user b
        both_user_ratings = both_users_ratings_each_movie_df[both_users_ratings_each_movie_df["user_b_id"] == user_b_id]
        if both_user_ratings.empty:
            continue
        user_a_rating_list = both_user_ratings["user_a_rating"].to_numpy()
        user_b_rating_list = both_user_ratings["user_b_rating"].to_numpy()

        # Calculate similarity between user a and b
        numerator = np.sum(np.multiply(user_a_rating_list - user_a_mean_rating, user_b_rating_list - user_b_mean_rating))
        denominator = np.sqrt(np.sum(np.multiply(user_a_rating_list - user_a_mean_rating, user_a_rating_list - user_a_mean_rating))) * np.sqrt(np.sum(np.multiply(user_b_rating_list - user_b_mean_rating, user_b_rating_list - user_b_mean_rating)))
        sim_a_b = numerator / denominator
        if sim_a_b >= threshold:
            similarities.append([user_b_id, user_b_mean_rating, sim_a_b])

    similarities.sort(key=lambda sim: sim[2], reverse=True) # Sort by similarity values, descending
    return similarities

# %%
group_sim_dfs = [] # Stores similarities tables of all users in the group
for user_id in group:
    sim_df = pd.DataFrame(calculate_similarities(user_id), columns=['User b ID', 'User b mean rating', 'sim(a,b)'])
    group_sim_dfs.append(sim_df)
group_sim_dfs[0] # Show similarity users of the first user in the group
# Out:
# C:\Users\minhn\AppData\Local\Temp\ipykernel_2660\319043352.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   sim_a_b = numerator / denominator
#      User b ID  User b mean rating  sim(a,b)
# 0          276            4.390244  1.000000
# 1           13            3.645161  1.000000
# 2           40            3.766990  1.000000
# 3           55            2.840000  1.000000
# 4           60            3.727273  1.000000
# ..         ...                 ...       ...
# 139        335            3.678571  0.532020
# 140        294            2.610984  0.529530
# 141        449            3.289474  0.518568
# 142        256            3.945402  0.511707
# 143        405            4.008333  0.505821
#
# [144 rows x 3 columns]

# %% [markdown]
# ### Make prediction of missing movie ratings for every user in the group

# %%
# Predict user a's missing movie ratings by the similarities table above
def make_prediction(user_a_id, sim_df, conn):
    print(f'Predict movie ratings for user ID: {user_a_id}')
    # Get user a mean rating and all movie ratings
    user_a_mean_rating = conn.execute(
        text("SELECT AVG(rating) FROM ratings WHERE userId = :uid"),
        {"uid": user_a_id}
    ).scalar()
    user_a_movie_ratings = pd.read_sql(
        text("""
            SELECT m.movieId, r.rating
            FROM movies m
            LEFT JOIN ratings r ON m.movieId = r.movieId AND r.userId = :uid
        """),
        conn,
        params={"uid": user_a_id}
    )

    # Get ratings of all similar users who rated the same movies as user a
    user_b_ids = tuple(sim_df["User b ID"].tolist())
    # Get movie IDs rated by user a
    user_a_rated_movies = pd.read_sql(
        text("SELECT movieId FROM ratings WHERE userId = :uid"),
        conn,
        params={"uid": user_a_id}
    )["movieId"].tolist()
    if not user_a_rated_movies:
        # If user a hasn't rated anything, fallback to empty DataFrame
        ratings_df = pd.DataFrame(columns=["userId", "movieId", "rating"])
    else:
        placeholders_users = ",".join(map(str, user_b_ids))
        ratings_df = pd.read_sql(
            text(f"""
                SELECT userId, movieId, rating
                FROM ratings
                WHERE userId IN ({placeholders_users})
            """),
            conn
        )

    # Compute predictions
    predictions = []
    for _, row in user_a_movie_ratings.iterrows():
        movie_id, rating = row["movieId"], row["rating"]
        if pd.notna(rating):
            predictions.append([movie_id, rating])
            continue
        # Get ratings for this movie from similar users
        user_b_ratings = ratings_df[ratings_df["movieId"] == movie_id]
        merged = pd.merge(user_b_ratings, sim_df, left_on="userId", right_on="User b ID")
        if merged.empty:
            predictions.append([movie_id, user_a_mean_rating])
            continue
        numerator = np.sum(merged["sim(a,b)"] * (merged["rating"] - merged["User b mean rating"]))
        denominator = np.sum(merged["sim(a,b)"])
        prediction = user_a_mean_rating + numerator / denominator if denominator != 0 else user_a_mean_rating
        prediction = np.clip(prediction, 0.5, 5.0)
        predictions.append([movie_id, prediction])
    
    return predictions

# %%
group_predicted_movie_ratings = [] # Stores predicted_movie_ratings tables of all users in the group
for i, sim_df in enumerate(group_sim_dfs):
    predicted_movie_ratings = pd.DataFrame(make_prediction(group[i], sim_df, conn), columns=['Movie ID', 'User a (predicted) movie rating'])
    predicted_movie_ratings = predicted_movie_ratings.astype({'Movie ID': int})
    group_predicted_movie_ratings.append(predicted_movie_ratings)
group_predicted_movie_ratings[0] # Show predicted ratings of the first user in the group
# Out:
# Predict movie ratings for user ID: 67
# Predict movie ratings for user ID: 80
# Predict movie ratings for user ID: 179
# Predict movie ratings for user ID: 286
# Predict movie ratings for user ID: 545
#       Movie ID  User a (predicted) movie rating
# 0            1                         4.223649
# 1            2                         4.162646
# 2            3                         3.331483
# 3            4                         2.937959
# 4            5                         3.392888
# ...        ...                              ...
# 9737    193581                         4.266998
# 9738    193583                         3.766998
# 9739    193585                         3.766998
# 9740    193587                         3.766998
# 9741    193609                         3.972222
#
# [9742 rows x 2 columns]

# %% [markdown]
# ## Option 2: Pearson - Jaccard similarity

# %% [markdown]
# ### New similarity function (Pearson - Jaccard similarity)

# %% [markdown]
# The Pearson - Jaccard similarity adjusts Pearson correlation by the proportion of co-rated items, preventing artificially high similarity scores for users who share very few ratings.
#
# Why Pearson - Jaccard?
#
# Pearson captures taste alignment; Jaccard significance captures overlap reliability.
# Combining them penalizes fake high correlations from tiny overlaps and rewards broader agreement.

# %%
rt = pd.read_sql(text("SELECT * FROM ratings"), conn)

# ratings_by_user[user][movie] = rating
ratings_by_user = defaultdict(dict)
for _, row in rt.iterrows():
    u = int(row["userId"])
    m = int(row["movieId"])
    r = float(row["rating"])
    ratings_by_user[u][m] = r

# user_mean[user] = average of that user's ratings
user_mean = {}
for u, umap in ratings_by_user.items():
    vals = list(umap.values())
    user_mean[u] = sum(vals) / len(vals)

# %%
def pearson_similarity(user_a: int, user_b: int, min_common: int = 2):
    # Grab each user's rating dict (movie -> rating)
    ra = ratings_by_user.get(user_a, {})
    rb = ratings_by_user.get(user_b, {})

    mean_a = user_mean[user_a]  # \bar r_a
    mean_b = user_mean[user_b]  # \bar r_b

    # Movies both have rated (the P set on the slide)
    common = [m for m in ra if m in rb]
    if len(common) < min_common:
        return mean_b, 0.0  # not enough overlap to trust a correlation

    # Compute numerator and denominator exactly as on the slide
    num = 0.0
    da2 = 0.0
    db2 = 0.0
    for m in common:
        da = ra[m] - mean_a          # (r_{a,m} - \bar r_a)
        db = rb[m] - mean_b          # (r_{b,m} - \bar r_b)
        num += da * db               # sum of products
        da2 += da * da               # sum of squares for a
        db2 += db * db               # sum of squares for b

    if da2 == 0.0 or db2 == 0.0:
        return mean_b, 0.0  # avoid divide-by-zero when one user has zero variance on common set

    return mean_b, num / ((da2 ** 0.5) * (db2 ** 0.5))

# --- Overlap helper ---
def jaccard_overlap(user_a: int, user_b: int) -> float:
    Ia = set(ratings_by_user.get(user_a, {}).keys())
    Ib = set(ratings_by_user.get(user_b, {}).keys())
    if not Ia or not Ib:
        return 0.0
    inter = len(Ia & Ib)
    if inter == 0:
        return 0.0
    union = len(Ia | Ib)
    return inter / union

# --- Pearson - Jaccard with significance (and optional case amplification) ---
def pearson_jaccard_similarity(
    user_a: int, user_b: int,
    min_common: int = 2,
    alpha: float = 0.7,      # Jaccard exponent (0.5–1.0 typical)
    cap_common: int = 50,    # significance cap C (30–50 good for MovieLens small)
    beta: float = 1.0,       # significance exponent (1.0–1.5)
    gamma: float = 1.0,      # case amplification (1.0 = off; try 1.3–1.5)
    allow_negative: bool = False
):
    # Base Pearson on co-rated set
    mean_b, p = pearson_similarity(user_a, user_b, min_common=min_common)
    if p == 0.0:
        return mean_b, 0.0
    if (not allow_negative) and p < 0:
        return mean_b, 0.0

    # Co-rated count for significance
    ra = ratings_by_user.get(user_a, {})
    rb = ratings_by_user.get(user_b, {})
    common = sum(1 for m in ra if m in rb)
    if common < min_common:
        return mean_b, 0.0

    # Reliability factors
    jac = jaccard_overlap(user_a, user_b)                     # [0,1]
    sig = min(common / cap_common, 1.0) ** beta               # [0,1]

    sim = p * (jac ** alpha) * sig

    # Optional case amplification
    if gamma != 1.0:
        sgn = 1.0 if sim >= 0 else -1.0
        sim = sgn * (abs(sim) ** gamma)

    return mean_b, sim

# %%
top_k_users = 50 # Top k users b with highest sim value for each user a in the group
group_new_sim_dfs = [] # Stores similarities tables of all users in the group
user_id_list = rt["userId"].unique()
for user_a_id in group:
    new_sim_list = []
    for user_b_id in user_id_list:
        if user_b_id == user_a_id:
            continue
        else:
            mean_rating_b, sim_a_b = pearson_jaccard_similarity(user_a_id, user_b_id)
            sim_a_b_row = [user_b_id, mean_rating_b, sim_a_b]
            new_sim_list.append(sim_a_b_row)
    new_sim_df = pd.DataFrame(new_sim_list, columns=['User b ID', 'User b mean rating', 'sim(a,b)'])
    new_sim_df = new_sim_df.sort_values(by="sim(a,b)", ascending=False)
    new_sim_df = new_sim_df[:top_k_users]
    group_new_sim_dfs.append(new_sim_df)
group_new_sim_dfs[0][:20] # Show similarity users of the first user in the group
# Out:
#      User b ID  User b mean rating  sim(a,b)
# 549        551            3.715447  0.063519
# 398        400            4.511628  0.041877
# 33          34            3.418605  0.041422
# 547        549            3.666667  0.039068
# 121        123            4.035714  0.034991
# 501        503            3.342105  0.034309
# 249        251            4.869565  0.033016
# 520        522            3.830000  0.031717
# 424        426            3.681818  0.029346
# 270        272            3.629032  0.029289
# 294        296            4.166667  0.026780
# 354        356            4.020761  0.026072
# 245        247            3.746667  0.025834
# 495        497            3.568627  0.024778
# 21          22            2.571429  0.024415
# 413        415            4.085106  0.024207
# 120        122            4.546233  0.024116
# 20          21            3.260722  0.023957
# 447        449            3.289474  0.023389
# 540        542            3.508850  0.023305

# %% [markdown]
# ### Make prediction based on the new similarity function (run the cell that contains make_prediction function first, if you skip option 1)

# %%
group_new_predicted_movie_ratings = [] # Stores predicted_movie_ratings tables of all users in the group
for i, sim_df in enumerate(group_new_sim_dfs):
    predicted_movie_ratings = pd.DataFrame(make_prediction(group[i], sim_df, conn), columns=['Movie ID', 'User a (predicted) movie rating'])
    predicted_movie_ratings = predicted_movie_ratings.astype({'Movie ID': int})
    group_new_predicted_movie_ratings.append(predicted_movie_ratings)
group_new_predicted_movie_ratings[0] # Show predicted ratings of the first user in the group
# Out:
# Predict movie ratings for user ID: 67
# Predict movie ratings for user ID: 80
# Predict movie ratings for user ID: 179
# Predict movie ratings for user ID: 286
# Predict movie ratings for user ID: 545
#       Movie ID  User a (predicted) movie rating
# 0            1                         4.356417
# 1            2                         3.658138
# 2            3                         3.281939
# 3            4                         3.972222
# 4            5                         3.972222
# ...        ...                              ...
# 9737    193581                         3.972222
# 9738    193583                         3.972222
# 9739    193585                         3.972222
# 9740    193587                         3.972222
# 9741    193609                         3.972222
#
# [9742 rows x 2 columns]

# %% [markdown]
# ## Compute disagreement between users in the group by rating difference between maximum and minimum ratings for each movie

# %% [markdown]
# ### Continue from option 1

# %%
# Merge all group members' predicted movie ratings into a single table by movie ID
merged_group_predicted_movie_ratings_df = group_predicted_movie_ratings[0]
merged_group_predicted_movie_ratings_df = merged_group_predicted_movie_ratings_df.rename(columns={'User a (predicted) movie rating': f'User {group[0]} (predicted) rating'})
for i in range(1, len(group_predicted_movie_ratings)):
    temp_predicted_movie_ratings_df = group_predicted_movie_ratings[i].rename(columns={'User a (predicted) movie rating': f'User {group[i]} (predicted) rating'})
    merged_group_predicted_movie_ratings_df = pd.merge(merged_group_predicted_movie_ratings_df, temp_predicted_movie_ratings_df, on="Movie ID")

# Add a new column for calculating rating differences between the max and min predicted ratings for each movie
merged_group_predicted_movie_ratings_df['Rating Difference'] = merged_group_predicted_movie_ratings_df[[f'User {user_id} (predicted) rating' for user_id in group]].max(axis=1) - merged_group_predicted_movie_ratings_df[[f'User {user_id} (predicted) rating' for user_id in group]].min(axis=1)
sorted_merged_group_predicted_movie_ratings_df = merged_group_predicted_movie_ratings_df.sort_values(by='Rating Difference')

# Get top n lowest rating difference
n_lowest_rating_diff = 1000
filtered_sorted_merged_group_predicted_movie_ratings_df = sorted_merged_group_predicted_movie_ratings_df[:n_lowest_rating_diff]
filtered_sorted_merged_group_predicted_movie_ratings_df
# Out:
#       Movie ID  User 67 (predicted) rating  User 80 (predicted) rating  \
# 9469    168366                    3.972222                    3.765345
# 6747     59387                    3.925989                    4.135479
# 14          15                    3.684925                    3.576420
# 4408      6502                    3.822615                    4.000000
# 751        986                    3.873471                    3.921085
# ...        ...                         ...                         ...
# 3044      4078                    3.972222                    4.260479
# 2650      3548                    4.087607                    4.260479
# 448        513                    3.972222                    4.260479
# 7164     71838                    3.972222                    3.765345
# 9247    155509                    4.112500                    4.260479
#
#       User 179 (predicted) rating  User 286 (predicted) rating  \
# ...

# %% [markdown]
# ### Continue from option 2

# %%
# Merge all group members' predicted movie ratings into a single table by movie ID
merged_group_new_predicted_movie_ratings_df = group_new_predicted_movie_ratings[0]
merged_group_new_predicted_movie_ratings_df = merged_group_new_predicted_movie_ratings_df.rename(columns={'User a (predicted) movie rating': f'User {group[0]} (predicted) rating'})
for i in range(1, len(group_new_predicted_movie_ratings)):
    temp_predicted_movie_ratings_df = group_new_predicted_movie_ratings[i].rename(columns={'User a (predicted) movie rating': f'User {group[i]} (predicted) rating'})
    merged_group_new_predicted_movie_ratings_df = pd.merge(merged_group_new_predicted_movie_ratings_df, temp_predicted_movie_ratings_df, on="Movie ID")

# Add a new column for calculating rating differences between the max and min predicted ratings for each movie
merged_group_new_predicted_movie_ratings_df['Rating Difference'] = merged_group_new_predicted_movie_ratings_df[[f'User {user_id} (predicted) rating' for user_id in group]].max(axis=1) - merged_group_new_predicted_movie_ratings_df[[f'User {user_id} (predicted) rating' for user_id in group]].min(axis=1)
sorted_merged_group_new_predicted_movie_ratings_df = merged_group_new_predicted_movie_ratings_df.sort_values(by='Rating Difference')

# Get top n lowest rating difference
n_lowest_rating_diff = 1000
filtered_sorted_merged_group_new_predicted_movie_ratings_df = sorted_merged_group_new_predicted_movie_ratings_df[:n_lowest_rating_diff]
filtered_sorted_merged_group_new_predicted_movie_ratings_df
# Out:
#       Movie ID  User 67 (predicted) rating  User 80 (predicted) rating  \
# 2890      3865                    3.972222                    4.001959
# 6151     44191                    4.010675                    4.000000
# 5379      8968                    3.972222                    3.796262
# 2189      2907                    3.972222                    3.770343
# 6497     53322                    4.043896                    4.000000
# ...        ...                         ...                         ...
# 3610      4958                    3.462531                    3.786912
# 635        808                    3.972222                    4.260479
# 9431    166492                    3.511306                    4.260479
# 44          48                    3.367826                    3.620420
# 7734     90717                    3.972222                    3.564016
#
#       User 179 (predicted) rating  User 286 (predicted) rating  \
# ...

# %% [markdown]
# ## Group recommendation

# %%
def group_recommendations_average(group_user_ratings, candidate_movies, topK=10, sort=True):
    rows = []
    for m in candidate_movies:
        member_scores = group_user_ratings[group_user_ratings['Movie ID'] == m].iloc[0, 1:].tolist()
        group_score = sum(member_scores) / len(member_scores)       # AVERAGE
        rows.append((m, group_score, member_scores))
    if sort:
        rows.sort(key=lambda t: t[1], reverse=True)
    return rows[:topK]

def group_recommendations_least_misery(group_user_ratings, candidate_movies, topK=10, sort=True):
    rows = []
    for m in candidate_movies:
        member_scores = group_user_ratings[group_user_ratings['Movie ID'] == m].iloc[0, 1:].tolist()
        group_score = min(member_scores)                            # LEAST MISERY
        rows.append((m, group_score, member_scores))
    if sort:
        rows.sort(key=lambda t: t[1], reverse=True)
    return rows[:topK]

# %%
mv = pd.read_sql(text("SELECT * FROM movies"), conn)
movie_title = dict(zip(mv.movieId, mv.title)) # map movieId -> title for nicer prints (optional)

#cands = filtered_and_sorted_merged_group_predicted_movie_ratings_df["Movie ID"] # Option 1
cands = filtered_sorted_merged_group_new_predicted_movie_ratings_df["Movie ID"] # Option 2

#group_user_ratings_1 = filtered_sorted_merged_group_predicted_movie_ratings_df.iloc[:, [0, 1, 2, 3, 4, 5]] # Option 1
group_user_ratings_2 = filtered_sorted_merged_group_new_predicted_movie_ratings_df.iloc[:, [0, 1, 2, 3, 4, 5]] # Option 2

top_k_movies = 20

# Option 1
# avg_list = group_recommendations_average(group_user_ratings_1, cands, topK)
# lm_list  = group_recommendations_least_misery(group_user_ratings_1, cands, topK)
# Option 2
avg_list = group_recommendations_average(group_user_ratings_2, cands, top_k_movies)
lm_list  = group_recommendations_least_misery(group_user_ratings_2, cands, top_k_movies)

print(f"\n=== GROUP RECS — AVERAGE (top-{top_k_movies}) ===")
for i, (m, score, per_user) in enumerate(avg_list, start=1):
    title = movie_title.get(m, f"movieId={m}")
    print(f"{i:>2}. (ID: {m}) {title}  | group_avg={score:.3f} | per-user: {', '.join(f'u{u}:{s:.2f}' for u,s in zip(group, per_user))}")

print(f"\n=== GROUP RECS — LEAST MISERY (top-{top_k_movies}) ===")
for i, (m, score, per_user) in enumerate(lm_list, start=1):
    title = movie_title.get(m, f"movieId={m}")
    print(f"{i:>2}. (ID: {m}) {title}  | group_min={score:.3f} | per-user: {', '.join(f'u{u}:{s:.2f}' for u,s in zip(group, per_user))}")
# Out:
# === GROUP RECS — AVERAGE (top-20) ===
#  1. (ID: 4878) Donnie Darko (2001)  | group_avg=4.568 | per-user: u67:4.29, u80:5.00, u179:4.87, u286:4.40, u545:4.28
#  2. (ID: 1197) Princess Bride, The (1987)  | group_avg=4.483 | per-user: u67:4.57, u80:4.86, u179:4.37, u286:4.40, u545:4.22
#  3. (ID: 16) Casino (1995)  | group_avg=4.410 | per-user: u67:4.30, u80:4.86, u179:4.18, u286:4.22, u545:4.49
#  4. (ID: 50) Usual Suspects, The (1995)  | group_avg=4.397 | per-user: u67:4.48, u80:4.50, u179:4.40, u286:4.58, u545:4.02
#  5. (ID: 1198) Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)  | group_avg=4.341 | per-user: u67:4.33, u80:4.74, u179:4.37, u286:4.21, u545:4.06
#  6. (ID: 1079) Fish Called Wanda, A (1988)  | group_avg=4.326 | per-user: u67:4.56, u80:4.61, u179:4.41, u286:4.08, u545:3.97
#  7. (ID: 2841) Stir of Echoes (1999)  | group_avg=4.289 | per-user: u67:4.46, u80:4.43, u179:4.37, u286:4.37, u545:3.82
# ...

# %% [markdown]
# # Part 2: Sequential group recommendation

# %%
# ======================================================
# Sequential Group Recs (SQUIRREL-style) — STRONGER SIGNAL
# - Action: SIAA
# - Reward: Satisfaction - Disagreement (Rsd)
# Tweaks implemented:
#   1) SIAA b = 0.25  (more weight on user satisfication)
#   2) Group with lower alignment (e.g., [67, 80, 179, 286, 545])
#   3) Stochastic environment per round:
#        - random candidate subset
#        - small Gaussian noise on predicted ratings
#   4) Longer horizon: num_iter = 40
# ======================================================

# -------------------------------
# 1) Prepare per-user predictions table with group average score 
# -------------------------------

# We will use the group movie ratings dataframe to which the Pearson - Jaccard similarity function is applied (option 2) during predictions
seq_gr_rec_movie_ratings_df = filtered_sorted_merged_group_new_predicted_movie_ratings_df.copy()
seq_gr_rec_movie_ratings_df = seq_gr_rec_movie_ratings_df.drop('Rating Difference', axis=1)

# Get group avg score for all n_lowest_rating_diff movies (we use average aggregation here)
avg_gr_rec_for_seq_gr_rec = group_recommendations_average(group_user_ratings_2, cands, n_lowest_rating_diff, False)
gr_avg_score = np.array([t[1] for t in avg_gr_rec_for_seq_gr_rec])
seq_gr_rec_movie_ratings_df['Group Avg Score'] = gr_avg_score

# Keep a clean, immutable copy of the original per-user predictions
member_cols = [f'User {uid} (predicted) rating' for uid in group]
_base_member_matrix = seq_gr_rec_movie_ratings_df[member_cols].values.copy()

seq_gr_rec_movie_ratings_df
# Out:
#       Movie ID  User 67 (predicted) rating  User 80 (predicted) rating  \
# 2890      3865                    3.972222                    4.001959
# 6151     44191                    4.010675                    4.000000
# 5379      8968                    3.972222                    3.796262
# 2189      2907                    3.972222                    3.770343
# 6497     53322                    4.043896                    4.000000
# ...        ...                         ...                         ...
# 3610      4958                    3.462531                    3.786912
# 635        808                    3.972222                    4.260479
# 9431    166492                    3.511306                    4.260479
# 44          48                    3.367826                    3.620420
# 7734     90717                    3.972222                    3.564016
#
#       User 179 (predicted) rating  User 286 (predicted) rating  \
# ...

# %%
# -------------------------------
# 2) SQUIRREL loop — stronger settings
# -------------------------------
num_iter = 40          # longer run for clearer trends
top_k_movies = 20
siaa_b = 0.25           # stronger emphasis on user satisfication
subset_frac = 0.60     # each round, sample ~60% of items as candidate universe
noise_sigma = 0.08     # Gaussian noise (std dev) on 1..5 scale to simulate drift

sat_u = []             # per-iteration per-user satisfaction
user_dis_u = []        # per-iteration per-user disagreement
satO_u = []            # per-iteration overall satisfaction per user
Rsd = []               # per-iteration reward
W_history = []         # track user weights per iteration (for heatmap)

# We will re-use the *original* per-user predictions, adding noise per round
for i in range(num_iter):
    # (a) create a noisy view of user ratings this round (non-stationarity)
    noise = np.random.normal(loc=0.0, scale=noise_sigma, size=_base_member_matrix.shape)
    noisy_member_matrix = np.clip(_base_member_matrix + noise, 0.5, 5.0)

    # (b) random candidate subset to force exploration
    if subset_frac < 1.0:
        subset_size = max(top_k_movies * 2, int(len(seq_gr_rec_movie_ratings_df) * subset_frac))
        round_index = np.random.choice(seq_gr_rec_movie_ratings_df.index, size=min(subset_size, len(seq_gr_rec_movie_ratings_df)), replace=False)
    else:
        round_index = seq_gr_rec_movie_ratings_df.index.values

    # Build a temporary DF view for this round with noisy scores
    round_df = seq_gr_rec_movie_ratings_df.loc[round_index].copy()
    for cix, col in enumerate(member_cols):
        round_df[col] = noisy_member_matrix[seq_gr_rec_movie_ratings_df.index.get_indexer(round_index), cix]

    # Initialize group score before weighting (plain mean of noisy scores)
    round_df['Group Avg Score'] = round_df[member_cols].mean(axis=1)

    # (c) Select top-k **this round** (based on current group score)
    df_sorted = round_df.sort_values(by='Group Avg Score', ascending=False)
    top_k_ids = df_sorted.index[:top_k_movies]

    # ---- Satisfaction per user this round ----
    sat_u_i = []
    for uid in group:
        col = f'User {uid} (predicted) rating'
        sat_num = round_df.loc[top_k_ids, col].sum()
        sat_den = round_df[col].nlargest(top_k_movies).sum()
        s = (sat_num / sat_den) if sat_den > 0 else 0.0
        sat_u_i.append(s)
    sat_u.append(sat_u_i)

    # ---- Disagreement per user this round ----
    max_sat = max(sat_u_i) if sat_u_i else 0.0
    user_dis_u_i = [max_sat - s for s in sat_u_i]
    user_dis_u.append(user_dis_u_i)

    # ---- Overall satisfaction up to now (mean across rounds so far) ----
    sat_u_arr = np.array(sat_u)  # shape: (i+1, |group|)
    satO_u_i = sat_u_arr.mean(axis=0).tolist()
    satO_u.append(satO_u_i)

    # ---- SIAA Weights ----
    if i == 0:
        w_u = np.random.rand(len(group))
        w_u = w_u / (w_u.sum() or 1.0)
    else:
        w_u = []
        prev_satO = satO_u[i - 1]
        prev_dis  = user_dis_u[i - 1]
        for u_idx in range(len(group)):
            # SIAA: (1 - b)*(1 - satO) + b*userDis
            w = (1 - siaa_b) * (1 - prev_satO[u_idx]) + siaa_b * prev_dis[u_idx]
            w_u.append(w)
        s = sum(w_u) or 1.0
        w_u = [x / s for x in w_u]
    W_history.append(w_u)

    # ---- Update group score for NEXT ROUND selection (over full universe, noisy) ----
    # Weighted sum on the whole noisy matrix, then write back to main DF
    weights_vec = np.array(w_u)
    new_scores_full = noisy_member_matrix.dot(weights_vec)  # scores for ALL items this round
    seq_gr_rec_movie_ratings_df['Group Avg Score'] = new_scores_full  # used in next round's subset ranking

    # ---- Reward Rsd for this iteration ----
    gr_satO = float(np.mean(satO_u_i))
    gr_disO = float(np.max(satO_u_i) - np.min(satO_u_i))
    Rsd_i = 2 * (gr_satO * (1 - gr_disO)) / (gr_satO + (1 - gr_disO)) if (gr_satO + (1 - gr_disO)) > 0 else 0.0
    Rsd.append(Rsd_i)

# -------------------------------
# 3) Final top-k after last update
# -------------------------------
final_topk = seq_gr_rec_movie_ratings_df.sort_values(by='Group Avg Score', ascending=False).head(top_k_movies)
print(f"\n=== FINAL TOP-{top_k_movies} (after last iteration, SIAA-weighted, stochastic env) ===")
for rank, (_, row) in enumerate(final_topk.iterrows(), start=1):
    movie_id = int(row['Movie ID'])
    title = movie_title.get(movie_id, None)
    per_user = ", ".join([f"u{uid}:{row[f'User {uid} (predicted) rating']:.2f}" for uid in group])
    print(f"{rank:>2}. (ID: {movie_id}) {title} | score={row['Group Avg Score']:.3f} | {per_user}")

#seq_gr_rec_movie_ratings_df.sort_values(by='Group Avg Score', ascending=False)[:top_k_movies]
# Out:
# === FINAL TOP-20 (after last iteration, SIAA-weighted, stochastic env) ===
#  1. (ID: 4878) Donnie Darko (2001) | score=4.530 | u67:4.29, u80:5.00, u179:4.87, u286:4.40, u545:4.28
#  2. (ID: 16) Casino (1995) | score=4.440 | u67:4.30, u80:4.86, u179:4.18, u286:4.22, u545:4.49
#  3. (ID: 1197) Princess Bride, The (1987) | score=4.439 | u67:4.57, u80:4.86, u179:4.37, u286:4.40, u545:4.22
#  4. (ID: 3836) Kelly's Heroes (1970) | score=4.397 | u67:4.46, u80:4.40, u179:3.78, u286:4.42, u545:4.32
#  5. (ID: 3683) Blood Simple (1984) | score=4.313 | u67:4.34, u80:4.29, u179:3.78, u286:4.45, u545:4.36
#  6. (ID: 50) Usual Suspects, The (1995) | score=4.303 | u67:4.48, u80:4.50, u179:4.40, u286:4.58, u545:4.02
#  7. (ID: 1198) Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981) | score=4.288 | u67:4.33, u80:4.74, u179:4.37, u286:4.21, u545:4.06
#  8. (ID: 6890) Elephant (2003) | score=4.269 | u67:4.52, u80:4.50, u179:3.78, u286:3.94, u545:4.36
# ...

# %%
# -------------------------------
# 4) Visualizations
# -------------------------------
sat_u_np = np.array(sat_u)          # (num_iter, |group|)
user_dis_u_np = np.array(user_dis_u)
satO_u_np = np.array(satO_u)
Rsd_np = np.array(Rsd)
W_hist_np = np.array(W_history)     # (num_iter, |group|)
iters = np.arange(1, num_iter + 1)

# Average satisfaction over iterations
avg_satisfaction = sat_u_np.mean(axis=1)
plt.figure(figsize=(8,5))
plt.plot(iters, avg_satisfaction, marker='o')
plt.title(f'Average User Satisfaction over Iterations (b={siaa_b}, noisy & subset)')
plt.xlabel('Iteration')
plt.ylabel('Average Satisfaction')
plt.grid(True)
plt.show()

# Average disagreement over iterations
avg_disagreement = user_dis_u_np.mean(axis=1)
plt.figure(figsize=(8,5))
plt.plot(iters, avg_disagreement, marker='o')
plt.title(f'Average User Disagreement over Iterations (b={siaa_b})')
plt.xlabel('Iteration')
plt.ylabel('Average Disagreement')
plt.grid(True)
plt.show()

# Reward (Rsd) over iterations
plt.figure(figsize=(8,5))
plt.plot(iters, Rsd_np, marker='s')
plt.title('Reward (Rsd) over Iterations — Longer Horizon')
plt.xlabel('Iteration')
plt.ylabel('Rsd')
plt.grid(True)
plt.show()

# Per-User Satisfaction lines
plt.figure(figsize=(9,6))
for idx, uid in enumerate(group):
    plt.plot(iters, sat_u_np[:, idx], marker='o', label=f'User {uid}')
plt.title('Per-User Satisfaction per Iteration (Less-aligned group)')
plt.xlabel('Iteration')
plt.ylabel('Satisfaction')
plt.legend()
plt.grid(True)
plt.show()

# User weight heatmap (how influence shifts)
plt.figure(figsize=(7,4))
plt.imshow(W_hist_np.T, aspect='auto', interpolation='nearest')
plt.colorbar(label='Weight')
plt.yticks(range(len(group)), [f'User {uid}' for uid in group])
plt.xticks(range(0, num_iter, max(1, num_iter // 10)), range(1, num_iter + 1, max(1, num_iter // 10)))
plt.title(f'Evolution of User Weights (SIAA, b={siaa_b})')
plt.xlabel('Iteration')
plt.ylabel('User')
plt.show()

# -------------------------------
# 5) Statistical summaries
# -------------------------------
print("\n=== SUMMARY STATS (Stronger Setting) ===")
print(f"Average Satisfaction: {avg_satisfaction[0]:.3f}  ->  {avg_satisfaction[-1]:.3f}")
print(f"Average Disagreement: {avg_disagreement[0]:.3f}  ->  {avg_disagreement[-1]:.3f}")
print(f"Reward (Rsd):         {Rsd_np[0]:.3f}  ->  {Rsd_np[-1]:.3f}")
print("\nPer-user Overall Satisfaction (satO) progression (first -> last):")
for idx, uid in enumerate(group):
    print(f"  User {uid}: {satO_u_np[0, idx]:.3f} -> {satO_u_np[-1, idx]:.3f}")
print("\nAverage user weights over run:")
for idx, uid in enumerate(group):
    print(f"  User {uid}: mean weight = {W_hist_np[:, idx].mean():.3f}  |  final = {W_hist_np[-1, idx]:.3f}")
# Out:
# === SUMMARY STATS (Stronger Setting) ===
# Average Satisfaction: 0.963  ->  0.960
# Average Disagreement: 0.024  ->  0.029
# Reward (Rsd):         0.949  ->  0.956
#
# Per-user Overall Satisfaction (satO) progression (first -> last):
#   User 67: 0.951 -> 0.953
#   User 80: 0.987 -> 0.983
#   User 179: 0.978 -> 0.968
#   User 286: 0.977 -> 0.974
#   User 545: 0.922 -> 0.933
#
# Average user weights over run:
#   User 67: mean weight = 0.255  |  final = 0.247
#   User 80: mean weight = 0.086  |  final = 0.078
#   User 179: mean weight = 0.156  |  final = 0.167
#   User 286: mean weight = 0.130  |  final = 0.132
#   User 545: mean weight = 0.373  |  final = 0.376

# %% [markdown]
# Explanation of the Statistical Summary (last update: 13.11.2025):
#
# 1. The results show that our sequential method keeps overall group satisfaction very high while significantly improving fairness. Average satisfaction remains stable (0.958 → 0.962), but disagreement between users drops by about 25%, meaning the system becomes much fairer over time.
# 2. The Rsd reward also increases (0.950 → 0.956), showing that the recommender is learning a better balance between satisfaction and fairness.
# 3. User 545 and 67, who started as the least satisfied, becomes better supported (0.927 → 0.932 and 0.933 → 0.952, respectively), while the weight heatmap shows the algorithm giving User 545 and 67 more influence (mean weight = 0.379 and 0.262, respectively).
# 4. This proves that the method successfully adapts to user needs, prioritizes under-served members, and improves fairness without reducing overall satisfaction.
#
# Why this method is better:
# 1. Our sequential approach does not treat each round independently; it learns from previous satisfaction and disagreement.
# 2. SIAA dynamically adjusts user weights, giving more influence to under-served members and achieving better fairness over time.
# 3. Even with fairness corrections, overall satisfaction stays high and stable, showing that the method does not compromise recommendation quality.
# 4. The reward and weight-heatmap demonstrate adaptive behavior that static averaging or Least Misery cannot provide.

# %% [markdown]
# # Part 3: Diversification in sequential group recommendation

# %% [markdown]
# Basic DisC algorithm is implemented in this project. Movie genres, year and group average score are three features for calculating distance/similarity between the movies.

# %%
# Append list of genres to the final_topk DataFrame
final_topk_with_movie_info = pd.merge(final_topk, mv, left_on='Movie ID', right_on='movieId', how='left')
final_topk_with_movie_info.drop('movieId', axis=1, inplace=True)
final_topk_with_movie_info['genres'] = [genres.split('|') for genres in final_topk_with_movie_info['genres']]

# Get top j (out of 18) genres in the top k movies above
top_j_genres = 10
genre_list_flatten = np.concatenate(final_topk_with_movie_info['genres'].to_numpy())
unique_genre_list, genre_count = np.unique(genre_list_flatten, return_counts=True)
sorted_genre_indices = np.argsort(genre_count)[::-1]
top_j_sorted_unique_genres = unique_genre_list[sorted_genre_indices][:top_j_genres]

# Append list of genres and year to the remaining_ratings DataFrame
remaining_ratings = seq_gr_rec_movie_ratings_df.sort_values(by='Group Avg Score', ascending=False)[top_k_movies:]
remaining_ratings_with_movie_info = pd.merge(remaining_ratings, mv, left_on='Movie ID', right_on='movieId', how='left')
remaining_ratings_with_movie_info.drop(remaining_ratings_with_movie_info.columns[[1, 2, 3, 4, 5]], axis=1, inplace=True) # Individual user ratings are not needed here
remaining_ratings_with_movie_info.drop('movieId', axis=1, inplace=True)
remaining_ratings_with_movie_info['genres'] = [genres.split('|') for genres in remaining_ratings_with_movie_info['genres']]
remaining_ratings_with_movie_info['year'] = [int(title[title.rfind('(') + 1 : title.rfind(')')]) for title in remaining_ratings_with_movie_info['title']]

# Calculate relevance between genres of remaining movies and the top j genres above
# It is calculated by proportion between number of genres appear in the top j genres and total number of genres in the movie
# For example, if the movie has 5 genres and 2 of them are in the top j genres list, the result is 2/5 = 0.4
# Values range from 0 to 1. The higher the value, the more genre relevant of the movie
remaining_ratings_with_movie_info['genres_norm'] = [np.round(np.intersect1d(genres, top_j_sorted_unique_genres).size / len(genres), 2) for genres in remaining_ratings_with_movie_info['genres']]

# Find the difference between the years of the oldest and newest movies, then normalize the years of all movies to values between 0 and 1
max_year = np.max(remaining_ratings_with_movie_info['year'])
min_year = np.min(remaining_ratings_with_movie_info['year'])
year_diff = max_year - min_year
remaining_ratings_with_movie_info['year_norm'] = [np.round((year - min_year) / year_diff, 2) for year in remaining_ratings_with_movie_info['year']]

# Find the difference between max and min group avg score, then normalize the scores of all movies to values between 0 and 1
max_score = np.max(remaining_ratings_with_movie_info['Group Avg Score'])
min_score = np.min(remaining_ratings_with_movie_info['Group Avg Score'])
score_diff = max_score - min_score
remaining_ratings_with_movie_info['score_norm'] = [np.round((score - min_score) / score_diff, 2) for score in remaining_ratings_with_movie_info['Group Avg Score']]

remaining_ratings_with_movie_info
# Out:
#      Movie ID  Group Avg Score                                  title  \
# 0        1228         4.169082                     Raging Bull (1980)
# 1        2203         4.168613               Shadow of a Doubt (1943)
# 2        1221         4.163281         Godfather: Part II, The (1974)
# 3       60684         4.158570                        Watchmen (2009)
# 4        1265         4.151807                   Groundhog Day (1993)
# ..        ...              ...                                    ...
# 975       586         3.198120                      Home Alone (1990)
# 976      1485         3.194739                       Liar Liar (1997)
# 977      1544         3.142512  Lost World: Jurassic Park, The (1997)
# 978       466         3.100414            Hot Shots! Part Deux (1993)
# 979      2054         2.979601        Honey, I Shrunk the Kids (1989)
#
#                                                genres  year  genres_norm  \
# ...

# %%
# Select movies (outside top k) using Basic-DisC algorithm
radius = 0.25 # You can scale the estimated number of movies here (should be in range (0,1))
movie_ids = remaining_ratings_with_movie_info['Movie ID'].to_numpy().copy()
movie_features = remaining_ratings_with_movie_info[['genres_norm','year_norm','score_norm']].to_numpy().copy()
selected_movie_ids = []
while movie_ids.size > 0:
    m_id = np.random.choice(movie_ids)
    m_index = np.where(movie_ids == m_id)[0][0]
    m_feature = movie_features[m_index]
    selected_movie_ids.append(m_id)
    distances = np.linalg.norm(movie_features - m_feature, axis=1) # Euclidean distance between selected movie and other (remaining) movies
    flags = distances > radius # Keep only movies that has True flag
    movie_ids = movie_ids[flags]
    movie_features = movie_features[flags]

# Since random choices are used, the result is different for each run
print('Some other movies that users may try besides top k movies:')
remaining_ratings_with_movie_info[remaining_ratings_with_movie_info['Movie ID'].isin(selected_movie_ids)]
# Out:
# Some other movies that users may try besides top k movies:
#      Movie ID  Group Avg Score  \
# 6       71535         4.149627
# 21       3675         4.100797
# 55      68597         4.060739
# 67      44931         4.052242
# 79     167036         4.040526
# 84       7264         4.037257
# 115      3448         4.017984
# 153     26003         3.987622
# 260      1652         3.916062
# 328      3865         3.866786
# 371    101864         3.843625
# 386      7050         3.838863
# 433      1024         3.817636
# 555      3102         3.760552
# 559      3372         3.758082
# 623      2205         3.723167
# 635    166015         3.716840
# 725      2517         3.678587
# 810      5076         3.641832
# 824     25746         3.630127
# 867    117533         3.603044
# 875      1029         3.592978
# 883      2089         3.584214
# 884    121253         3.583573
# 917    160080         3.523561
# 942      4270         3.454271
# 951     26198         3.427864
# ...

# %% [markdown]
# # Close the connection

# %%
conn.close()
