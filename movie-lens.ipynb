# %% [markdown]
# # Import packages

# %%
from sqlalchemy import create_engine
from sqlalchemy.sql import text
import numpy as np
import pandas as pd

# %% [markdown]
# # Database connection

# %%
engine = create_engine('sqlite:///movie-lens.db', echo = False)
conn = engine.connect()

# %% [markdown]
# # User-based collaborative filtering using the Pearson correlation function

# %%
def calculate_similarities(user_a_id, threshold = 0.5):
    # Get mean rating of user a
    user_a_mean_rating_query = text(f'SELECT AVG(rating) FROM ratings WHERE userId = {user_a_id}')
    user_a_mean_rating_result = conn.execute(user_a_mean_rating_query)
    user_a_mean_rating = user_a_mean_rating_result.fetchone()[0]
    # Get all other user b IDs who are in 'ratings' table
    user_b_ids_query = text(f'SELECT DISTINCT userId FROM ratings WHERE userId != {user_a_id}')
    user_b_ids_result = conn.execute(user_b_ids_query)
    user_b_ids = np.array(user_b_ids_result.fetchall()).transpose()[0]
    similarities = [] # Similarity between the user a and every user b
    for user_b_id in user_b_ids:
        # Get rating of user a and user b for each movie which is rated by both users
        both_users_ratings_each_movie_query = text(f'SELECT r1.movieId, r1.userId, r1.rating, r2.userId, r2.rating FROM ratings r1, ratings r2 WHERE r1.userId = {user_a_id} AND r2.userId = {user_b_id} AND r1.movieId = r2.movieId')
        both_users_ratings_each_movie_result = conn.execute(both_users_ratings_each_movie_query)
        both_users_ratings_each_movie = both_users_ratings_each_movie_result.fetchall()
        if both_users_ratings_each_movie.__len__() == 0:
            continue
        _ , _, user_a_rating_list, _, user_b_rating_list = zip(*both_users_ratings_each_movie)
        user_a_rating_list = np.array(user_a_rating_list)
        user_b_rating_list = np.array(user_b_rating_list)
        # Get mean rating of user b
        user_b_mean_rating_query = text(f'SELECT AVG(rating) FROM ratings WHERE userId = {user_b_id}')
        user_b_mean_rating_result = conn.execute(user_b_mean_rating_query)
        user_b_mean_rating = user_b_mean_rating_result.fetchone()[0]
        # Calculate similarity between user a and b
        numerator = np.sum(np.multiply(user_a_rating_list - user_a_mean_rating, user_b_rating_list - user_b_mean_rating))
        denominator = np.sqrt(np.sum(np.multiply(user_a_rating_list - user_a_mean_rating, user_a_rating_list - user_a_mean_rating))) * np.sqrt(np.sum(np.multiply(user_b_rating_list - user_b_mean_rating, user_b_rating_list - user_b_mean_rating)))
        sim_a_b = numerator / denominator
        if sim_a_b >= threshold:
            similarities.append([user_b_id, user_b_mean_rating, sim_a_b])
    similarities.sort(key=lambda sim: sim[2], reverse=True) # Sort by similarity values, descending
    return similarities

# %%
sim_list = calculate_similarities(1)
print('User b ID    User b mean rating    sim(a,b)')
sim_list
# Out:
# C:\Users\minhn\AppData\Local\Temp\ipykernel_20692\3648850243.py:28: RuntimeWarning: invalid value encountered in scalar divide
#   sim_a_b = numerator / denominator
# User b ID    User b mean rating    sim(a,b)
# [[77, 4.0, 1.0000000000000002],
#  [12, 4.390625, 1.0],
#  [85, 3.7058823529411766, 1.0],
#  [253, 4.351063829787234, 1.0],
#  [291, 4.258064516129032, 1.0],
#  [358, 3.2560975609756095, 1.0],
#  [388, 3.6206896551724137, 1.0],
#  [2, 3.9482758620689653, 0.9999999999999998],
#  [146, 3.140625, 0.9990496408681655],
#  [278, 3.875, 0.9710607611177227],
#  [550, 4.107142857142857, 0.9500648497978605],
#  [13, 3.6451612903225805, 0.9478788458420679],
#  [127, 3.1136363636363638, 0.9406906663964631],
#  [333, 2.64, 0.9379233588635404],
#  [472, 4.120689655172414, 0.9293520860459321],
#  [157, 3.4761904761904763, 0.901774575834698],
#  [139, 2.1443298969072164, 0.8903416876712336],
#  [401, 3.5277777777777777, 0.8713212630061857],
#  [511, 4.125, 0.8655816064894617],
#  [473, 3.418918918918919, 0.840746829564101],
#  [366, 3.9516129032258065, 0.8352756122978426],
#  [258, 4.2, 0.8320502943378436],
#  [65, 4.029411764705882, 0.8235706673737208],
#  [487, 3.142857142857143, 0.8220948302697891],
#  [90, 4.074074074074074, 0.8214224137571167],
#  [180, 3.5625, 0.812323733591591],
#  [499, 3.8333333333333335, 0.8009893836412011],
#  [430, 3.7413793103448274, 0.792673331599083],
#  [207, 2.875, 0.7722519995654104],
#  [49, 4.261904761904762, 0.7526685694780164],
#  [535, 2.6666666666666665, 0.7465137267234351],
#  [114, 3.435483870967742, 0.7439847032746658],
#  [154, 4.382352941176471, 0.7122202243459141],
#  [162, 4.2368421052631575, 0.6939887258055054],
#  [210, 4.079710144927536, 0.6842827829019166],
#  [398, 4.25, 0.6657357370608938],
#  [505, 4.17741935483871, 0.6581927982722249],
#  [324, 3.142857142857143, 0.6507913734559686],
#  [206, 4.04, 0.6378635032837362],
#  [478, 2.8181818181818183, 0.6368783518755518],
#  [369, 3.391472868217054, 0.6281219378489326],
#  [421, 4.108108108108108, 0.6138774053700462],
#  [375, 3.909090909090909, 0.6092718936364474],
#  [44, 3.3541666666666665, 0.608688341760208],
#  [467, 3.409090909090909, 0.6019589578818442],
#  [297, 2.5972222222222223, 0.5836796515968914],
#  [431, 2.725, 0.5828627787918391],
#  [445, 3.857142857142857, 0.5817744754393003],
#  [72, 4.155555555555556, 0.5798547717605266],
#  [494, 4.2272727272727275, 0.5772849193621854],
#  [236, 3.966666666666667, 0.5680348832136561],
#  [596, 3.495133819951338, 0.5626528403219744],
#  [595, 4.2, 0.5588814721805508],
#  [178, 4.090909090909091, 0.5427107863446915],
#  [301, 3.3201754385964914, 0.5426370552515191],
#  [479, 3.320441988950276, 0.540738895771055],
#  [360, 3.36, 0.5372608625699853],
#  [450, 4.0, 0.5368200782385798],
#  [516, 3.6923076923076925, 0.5261754701664372],
#  [20, 3.590909090909091, 0.5256863271011928],
#  [120, 3.409090909090909, 0.5228781610344042],
#  [47, 3.0535714285714284, 0.5190549613113596],
#  [113, 3.6466666666666665, 0.5152989716673757],
#  [300, 4.296875, 0.51512964126458],
#  [62, 4.081967213114754, 0.509486184626367],
#  [209, 4.242857142857143, 0.5090743087666184],
#  [442, 1.275, 0.5004253976674229]]

# %%
def make_prediction(user_a_id, sim_list, conn):
    sim_df = pd.DataFrame(sim_list, columns=["user_b_id", "user_b_mean", "similarity"])
    
    # Get user a mean rating and all movie ratings
    user_a_mean_rating = conn.execute(
        text("SELECT AVG(rating) FROM ratings WHERE userId = :uid"),
        {"uid": user_a_id}
    ).scalar()
    user_a_movie_ratings = pd.read_sql(
        text("""
            SELECT m.movieId, r.rating
            FROM movies m
            LEFT JOIN ratings r ON m.movieId = r.movieId AND r.userId = :uid
        """),
        conn,
        params={"uid": user_a_id}
    )

    # Get ratings of all similar users who rated the same movies as user a
    user_b_ids = tuple(sim_df["user_b_id"].tolist())
    # Get movie IDs rated by user a
    user_a_rated_movies = pd.read_sql(
        text("SELECT movieId FROM ratings WHERE userId = :uid"),
        conn,
        params={"uid": user_a_id}
    )["movieId"].tolist()
    if not user_a_rated_movies:
        # If user a hasn't rated anything, fallback to empty DataFrame
        ratings_df = pd.DataFrame(columns=["userId", "movieId", "rating"])
    else:
        placeholders_users = ",".join(map(str, user_b_ids))
        placeholders_movies = ",".join(map(str, user_a_rated_movies))
        ratings_df = pd.read_sql(
            text(f"""
                SELECT userId, movieId, rating
                FROM ratings
                WHERE userId IN ({placeholders_users})
                AND movieId IN ({placeholders_movies})
            """),
            conn
        )

    # Compute predictions
    predictions = []
    for _, row in user_a_movie_ratings.iterrows():
        movie_id, rating = row["movieId"], row["rating"]
        if pd.notna(rating):
            predictions.append([movie_id, rating])
            continue
        # Get ratings for this movie from similar users
        user_b_ratings = ratings_df[ratings_df["movieId"] == movie_id]
        merged = pd.merge(user_b_ratings, sim_df, left_on="userId", right_on="user_b_id")
        if merged.empty:
            predictions.append([movie_id, user_a_mean_rating])
            continue
        numerator = np.sum(merged["similarity"] * (merged["rating"] - merged["user_b_mean"]))
        denominator = np.sum(merged["similarity"])
        prediction = user_a_mean_rating + numerator / denominator if denominator != 0 else user_a_mean_rating
        predictions.append([movie_id, prediction])
    
    return predictions

# %%
predicted_movie_ratings = make_prediction(1, sim_list, conn)

# %%
#predicted_movie_ratings.sort(key=lambda pred: pred[1], reverse=True) # Sort by prediction values
print('Movie ID    User a predicted movie rating')
predicted_movie_ratings
# Out:
# Movie ID    User a predicted movie rating
# [[1.0, 4.0],
#  [2.0, 4.366379310344827],
#  [3.0, 4.0],
#  [4.0, 4.366379310344827],
#  [5.0, 4.366379310344827],
#  [6.0, 4.0],
#  [7.0, 4.366379310344827],
#  [8.0, 4.366379310344827],
#  [9.0, 4.366379310344827],
#  [10.0, 4.366379310344827],
#  [11.0, 4.366379310344827],
#  [12.0, 4.366379310344827],
#  [13.0, 4.366379310344827],
#  [14.0, 4.366379310344827],
#  [15.0, 4.366379310344827],
#  [16.0, 4.366379310344827],
#  [17.0, 4.366379310344827],
#  [18.0, 4.366379310344827],
#  [19.0, 4.366379310344827],
#  [20.0, 4.366379310344827],
#  [21.0, 4.366379310344827],
#  [22.0, 4.366379310344827],
#  [23.0, 4.366379310344827],
#  [24.0, 4.366379310344827],
#  [25.0, 4.366379310344827],
#  [26.0, 4.366379310344827],
#  [27.0, 4.366379310344827],
#  [28.0, 4.366379310344827],
#  [29.0, 4.366379310344827],
#  [30.0, 4.366379310344827],
#  [31.0, 4.366379310344827],
#  [32.0, 4.366379310344827],
#  [34.0, 4.366379310344827],
#  [36.0, 4.366379310344827],
#  [38.0, 4.366379310344827],
#  [39.0, 4.366379310344827],
#  [40.0, 4.366379310344827],
#  [41.0, 4.366379310344827],
#  [42.0, 4.366379310344827],
#  [43.0, 4.366379310344827],
#  [44.0, 4.366379310344827],
#  [45.0, 4.366379310344827],
#  [46.0, 4.366379310344827],
#  [47.0, 5.0],
#  [48.0, 4.366379310344827],
#  [49.0, 4.366379310344827],
#  [50.0, 5.0],
#  [52.0, 4.366379310344827],
#  [53.0, 4.366379310344827],
#  [54.0, 4.366379310344827],
#  [55.0, 4.366379310344827],
#  [57.0, 4.366379310344827],
#  [58.0, 4.366379310344827],
#  [60.0, 4.366379310344827],
#  [61.0, 4.366379310344827],
#  [62.0, 4.366379310344827],
#  [63.0, 4.366379310344827],
#  [64.0, 4.366379310344827],
#  [65.0, 4.366379310344827],
#  [66.0, 4.366379310344827],
#  [68.0, 4.366379310344827],
#  [69.0, 4.366379310344827],
#  [70.0, 3.0],
#  [71.0, 4.366379310344827],
#  [72.0, 4.366379310344827],
#  [73.0, 4.366379310344827],
#  [74.0, 4.366379310344827],
#  [75.0, 4.366379310344827],
#  [76.0, 4.366379310344827],
#  [77.0, 4.366379310344827],
#  [78.0, 4.366379310344827],
#  [79.0, 4.366379310344827],
#  [80.0, 4.366379310344827],
#  [81.0, 4.366379310344827],
#  [82.0, 4.366379310344827],
#  [83.0, 4.366379310344827],
#  [85.0, 4.366379310344827],
#  [86.0, 4.366379310344827],
#  [87.0, 4.366379310344827],
#  [88.0, 4.366379310344827],
#  [89.0, 4.366379310344827],
#  [92.0, 4.366379310344827],
#  [93.0, 4.366379310344827],
#  [94.0, 4.366379310344827],
#  [95.0, 4.366379310344827],
#  [96.0, 4.366379310344827],
#  [97.0, 4.366379310344827],
#  [99.0, 4.366379310344827],
#  [100.0, 4.366379310344827],
#  [101.0, 5.0],
#  [102.0, 4.366379310344827],
#  [103.0, 4.366379310344827],
#  [104.0, 4.366379310344827],
#  [105.0, 4.366379310344827],
#  [106.0, 4.366379310344827],
#  [107.0, 4.366379310344827],
#  [108.0, 4.366379310344827],
#  [110.0, 4.0],
#  [111.0, 4.366379310344827],
#  [112.0, 4.366379310344827],
#  [113.0, 4.366379310344827],
#  [116.0, 4.366379310344827],
#  [117.0, 4.366379310344827],
#  [118.0, 4.366379310344827],
#  [119.0, 4.366379310344827],
#  [121.0, 4.366379310344827],
#  [122.0, 4.366379310344827],
#  [123.0, 4.366379310344827],
#  [125.0, 4.366379310344827],
#  [126.0, 4.366379310344827],
#  [128.0, 4.366379310344827],
#  [129.0, 4.366379310344827],
#  [132.0, 4.366379310344827],
#  [135.0, 4.366379310344827],
#  [540.0, 4.366379310344827],
#  [541.0, 4.366379310344827],
#  [542.0, 4.366379310344827],
#  [543.0, 4.0],
#  [544.0, 4.366379310344827],
#  [546.0, 4.366379310344827],
#  [547.0, 4.366379310344827],
#  [548.0, 4.366379310344827],
#  [549.0, 4.366379310344827],
#  [550.0, 4.366379310344827],
#  [551.0, 4.366379310344827],
#  [552.0, 4.0],
#  [553.0, 5.0],
#  [555.0, 4.366379310344827],
#  [556.0, 4.366379310344827],
#  [558.0, 4.366379310344827],
#  [562.0, 4.366379310344827],
#  [563.0, 4.366379310344827],
#  [564.0, 4.366379310344827],
#  [567.0, 4.366379310344827],
#  [568.0, 4.366379310344827],
#  [569.0, 4.366379310344827],
#  [573.0, 4.366379310344827],
#  [574.0, 4.366379310344827],
#  [575.0, 4.366379310344827],
#  [577.0, 4.366379310344827],
#  [579.0, 4.366379310344827],
#  [580.0, 4.366379310344827],
#  [581.0, 4.366379310344827],
#  [583.0, 4.366379310344827],
#  [585.0, 4.366379310344827],
#  [586.0, 4.366379310344827],
#  [587.0, 4.366379310344827],
#  [588.0, 4.366379310344827],
#  [589.0, 4.366379310344827],
#  [590.0, 4.0],
#  [592.0, 4.0],
#  [593.0, 4.0],
#  [594.0, 4.366379310344827],
#  [595.0, 4.366379310344827],
#  [596.0, 5.0],
#  [597.0, 4.366379310344827],
#  [599.0, 4.366379310344827],
#  [600.0, 4.366379310344827],
#  [602.0, 4.366379310344827],
#  [605.0, 4.366379310344827],
#  [606.0, 4.366379310344827],
#  [608.0, 5.0],
#  [609.0, 4.366379310344827],
#  [610.0, 4.366379310344827],
#  [611.0, 4.366379310344827],
#  [612.0, 4.366379310344827],
#  [613.0, 4.366379310344827],
#  [615.0, 4.366379310344827],
#  [616.0, 4.366379310344827],
#  [617.0, 4.366379310344827],
#  [618.0, 4.366379310344827],
#  [619.0, 4.366379310344827],
#  [626.0, 4.366379310344827],
#  [627.0, 4.366379310344827],
#  [628.0, 4.366379310344827],
#  [631.0, 4.366379310344827],
#  [632.0, 4.366379310344827],
#  [633.0, 4.366379310344827],
#  [634.0, 4.366379310344827],
#  [635.0, 4.366379310344827],
#  [636.0, 4.366379310344827],
#  [637.0, 4.366379310344827],
#  [638.0, 4.366379310344827],
#  [639.0, 4.366379310344827],
#  [640.0, 4.366379310344827],
#  [645.0, 4.366379310344827],
#  [647.0, 4.366379310344827],
#  [648.0, 3.0],
#  [649.0, 4.366379310344827],
#  [650.0, 4.366379310344827],
#  [653.0, 4.366379310344827],
#  [656.0, 4.366379310344827],
#  [661.0, 5.0],
#  [662.0, 4.366379310344827],
#  [663.0, 4.366379310344827],
#  [665.0, 4.366379310344827],
#  [667.0, 4.366379310344827],
#  [668.0, 4.366379310344827],
#  [670.0, 4.366379310344827],
#  [671.0, 4.366379310344827],
#  [673.0, 3.0],
#  [674.0, 4.366379310344827],
#  [678.0, 4.366379310344827],
#  [679.0, 4.366379310344827],
#  [680.0, 4.366379310344827],
#  [685.0, 4.366379310344827],
#  [688.0, 4.366379310344827],
#  [691.0, 4.366379310344827],
#  [692.0, 4.366379310344827],
#  [694.0, 4.366379310344827],
#  [695.0, 4.366379310344827],
#  [697.0, 4.366379310344827],
#  [698.0, 4.366379310344827],
#  [700.0, 4.366379310344827],
#  [703.0, 4.366379310344827],
#  [704.0, 4.366379310344827],
#  [706.0, 4.366379310344827],
#  [707.0, 4.366379310344827],
#  [708.0, 4.366379310344827],
#  [709.0, 4.366379310344827],
#  [710.0, 4.366379310344827],
#  [711.0, 4.366379310344827],
#  [714.0, 4.366379310344827],
#  [715.0, 4.366379310344827],
#  [718.0, 4.366379310344827],
#  [719.0, 4.366379310344827],
#  [720.0, 4.366379310344827],
#  [722.0, 4.366379310344827],
#  [724.0, 4.366379310344827],
#  [725.0, 4.366379310344827],
#  [726.0, 4.366379310344827],
#  [728.0, 4.366379310344827],
#  [731.0, 4.366379310344827],
#  [733.0, 4.0],
#  [735.0, 4.366379310344827],
#  [736.0, 3.0],
#  [737.0, 4.366379310344827],
#  [741.0, 4.366379310344827],
#  [742.0, 4.366379310344827],
#  [743.0, 4.366379310344827],
#  [745.0, 4.366379310344827],
#  [747.0, 4.366379310344827],
#  [748.0, 4.366379310344827],
#  [750.0, 4.366379310344827],
#  [757.0, 4.366379310344827],
#  [759.0, 4.366379310344827],
#  [760.0, 4.366379310344827],
#  [761.0, 4.366379310344827],
#  [762.0, 4.366379310344827],
#  [764.0, 4.366379310344827],
#  [765.0, 4.366379310344827],
#  [766.0, 4.366379310344827],
#  [773.0, 4.366379310344827],
#  [775.0, 4.366379310344827],
#  [778.0, 4.366379310344827],
#  [779.0, 4.366379310344827],
#  [780.0, 3.0],
#  [781.0, 4.366379310344827],
#  [782.0, 4.366379310344827],
#  [783.0, 4.366379310344827],
#  [784.0, 4.366379310344827],
#  [785.0, 4.366379310344827],
#  [786.0, 4.366379310344827],
#  [788.0, 4.366379310344827],
#  [790.0, 4.366379310344827],
#  [791.0, 4.366379310344827],
#  [795.0, 4.366379310344827],
#  [798.0, 4.366379310344827],
#  [799.0, 4.366379310344827],
#  [800.0, 4.366379310344827],
#  [801.0, 4.366379310344827],
#  [802.0, 4.366379310344827],
#  [803.0, 4.366379310344827],
#  [804.0, 4.0],
#  [805.0, 4.366379310344827],
#  [806.0, 4.366379310344827],
#  [808.0, 4.366379310344827],
#  [809.0, 4.366379310344827],
#  [810.0, 4.366379310344827],
#  [813.0, 4.366379310344827],
#  [818.0, 4.366379310344827],
#  [823.0, 4.366379310344827],
#  [824.0, 4.366379310344827],
#  [828.0, 4.366379310344827],
#  [829.0, 4.366379310344827],
#  [830.0, 4.366379310344827],
#  [832.0, 4.366379310344827],
#  [833.0, 4.366379310344827],
#  [835.0, 4.366379310344827],
#  [836.0, 4.366379310344827],
#  [837.0, 4.366379310344827],
#  [838.0, 4.366379310344827],
#  [839.0, 4.366379310344827],
#  [840.0, 4.366379310344827],
#  [841.0, 4.366379310344827],
#  [842.0, 4.366379310344827],
#  [848.0, 4.366379310344827],
#  [849.0, 4.366379310344827],
#  [851.0, 4.366379310344827],
#  [852.0, 4.366379310344827],
#  [858.0, 4.366379310344827],
#  [861.0, 4.366379310344827],
#  [866.0, 4.366379310344827],
#  [867.0, 4.366379310344827],
#  [869.0, 4.366379310344827],
#  [870.0, 4.366379310344827],
#  [875.0, 4.366379310344827],
#  [876.0, 4.366379310344827],
#  [879.0, 4.366379310344827],
#  [880.0, 4.366379310344827],
#  [881.0, 4.366379310344827],
#  [882.0, 4.366379310344827],
#  [885.0, 4.366379310344827],
#  [886.0, 4.366379310344827],
#  [888.0, 4.366379310344827],
#  [889.0, 4.366379310344827],
#  [891.0, 4.366379310344827],
#  [892.0, 4.366379310344827],
#  [893.0, 4.366379310344827],
#  [896.0, 4.366379310344827],
#  [897.0, 4.366379310344827],
#  [898.0, 4.366379310344827],
#  [899.0, 4.366379310344827],
#  [900.0, 4.366379310344827],
#  [901.0, 4.366379310344827],
#  [902.0, 4.366379310344827],
#  [903.0, 4.366379310344827],
#  [904.0, 4.366379310344827],
#  [905.0, 4.366379310344827],
#  [906.0, 4.366379310344827],
#  [907.0, 4.366379310344827],
#  [908.0, 4.366379310344827],
#  [909.0, 4.366379310344827],
#  [910.0, 4.366379310344827],
#  [911.0, 4.366379310344827],
#  [912.0, 4.366379310344827],
#  [913.0, 4.366379310344827],
#  [914.0, 4.366379310344827],
#  [915.0, 4.366379310344827],
#  [916.0, 4.366379310344827],
#  [917.0, 4.366379310344827],
#  [918.0, 4.366379310344827],
#  [919.0, 5.0],
#  [920.0, 4.366379310344827],
#  [921.0, 4.366379310344827],
#  [922.0, 4.366379310344827],
#  [923.0, 5.0],
#  [924.0, 4.366379310344827],
#  [926.0, 4.366379310344827],
#  [927.0, 4.366379310344827],
#  [928.0, 4.366379310344827],
#  [929.0, 4.366379310344827],
#  [930.0, 4.366379310344827],
#  [931.0, 4.366379310344827],
#  [932.0, 4.366379310344827],
#  [933.0, 4.366379310344827],
#  [934.0, 4.366379310344827],
#  [935.0, 4.366379310344827],
#  [936.0, 4.366379310344827],
#  [937.0, 4.366379310344827],
#  [938.0, 4.366379310344827],
#  [940.0, 5.0],
#  [941.0, 4.366379310344827],
#  [942.0, 4.366379310344827],
#  [943.0, 4.0],
#  [944.0, 4.366379310344827],
#  [945.0, 4.366379310344827],
#  [946.0, 4.366379310344827],
#  [947.0, 4.366379310344827],
#  [948.0, 4.366379310344827],
#  [949.0, 4.366379310344827],
#  [950.0, 4.366379310344827],
#  [951.0, 4.366379310344827],
#  [952.0, 4.366379310344827],
#  [953.0, 4.366379310344827],
#  [954.0, 5.0],
#  [955.0, 4.366379310344827],
#  [956.0, 4.366379310344827],
#  [959.0, 4.366379310344827],
#  [961.0, 4.366379310344827],
#  [963.0, 4.366379310344827],
#  [965.0, 4.366379310344827],
#  [968.0, 4.366379310344827],
#  [969.0, 4.366379310344827],
#  [970.0, 4.366379310344827],
#  [971.0, 4.366379310344827],
#  [973.0, 4.366379310344827],
#  [976.0, 4.366379310344827],
#  [979.0, 4.366379310344827],
#  [981.0, 4.366379310344827],
#  [982.0, 4.366379310344827],
#  [984.0, 4.366379310344827],
#  [986.0, 4.366379310344827],
#  [987.0, 4.366379310344827],
#  [988.0, 4.366379310344827],
#  [990.0, 4.366379310344827],
#  [991.0, 4.366379310344827],
#  [993.0, 4.366379310344827],
#  [994.0, 4.366379310344827],
#  [996.0, 4.366379310344827],
#  [998.0, 4.366379310344827],
#  [999.0, 4.366379310344827],
#  [1003.0, 4.366379310344827],
#  [1004.0, 4.366379310344827],
#  [1005.0, 4.366379310344827],
#  [1006.0, 4.366379310344827],
#  [1007.0, 4.366379310344827],
#  [1008.0, 4.366379310344827],
#  [1009.0, 3.0],
#  [1010.0, 4.366379310344827],
#  [1011.0, 4.366379310344827],
#  [1012.0, 4.366379310344827],
#  [1013.0, 4.366379310344827],
#  [1014.0, 4.366379310344827],
#  [1015.0, 4.366379310344827],
#  [1016.0, 4.366379310344827],
#  [1017.0, 4.366379310344827],
#  [1018.0, 4.366379310344827],
#  [1019.0, 4.366379310344827],
#  [1020.0, 4.366379310344827],
#  [1021.0, 4.366379310344827],
#  [1022.0, 4.366379310344827],
#  [1023.0, 5.0],
#  [1024.0, 5.0],
#  [1025.0, 5.0],
#  [1027.0, 4.366379310344827],
#  [1028.0, 4.366379310344827],
#  [1029.0, 5.0],
#  [1030.0, 3.0],
#  [1031.0, 5.0],
#  [1032.0, 5.0],
#  [1033.0, 4.366379310344827],
#  [1034.0, 4.366379310344827],
#  [1035.0, 4.366379310344827],
#  [1036.0, 4.366379310344827],
#  [1037.0, 4.366379310344827],
#  [1040.0, 4.366379310344827],
#  [1041.0, 4.366379310344827],
#  [1042.0, 4.0],
#  [1043.0, 4.366379310344827],
#  [1046.0, 4.366379310344827],
#  [1047.0, 4.366379310344827],
#  [1049.0, 5.0],
#  [1050.0, 4.366379310344827],
#  [1051.0, 4.366379310344827],
#  [1053.0, 4.366379310344827],
#  [1054.0, 4.366379310344827],
#  [1055.0, 4.366379310344827],
#  [1056.0, 4.366379310344827],
#  [1057.0, 4.366379310344827],
#  [1059.0, 4.366379310344827],
#  [1060.0, 4.0],
#  [1061.0, 4.366379310344827],
#  [1064.0, 4.366379310344827],
#  [1066.0, 4.366379310344827],
#  [1068.0, 4.366379310344827],
#  [1073.0, 5.0],
#  [1076.0, 4.366379310344827],
#  [1077.0, 4.366379310344827],
#  [1078.0, 4.366379310344827],
#  [1079.0, 4.366379310344827],
#  [1080.0, 5.0],
#  [1081.0, 4.366379310344827],
#  [1082.0, 4.366379310344827],
#  [1083.0, 4.366379310344827],
#  [1084.0, 4.366379310344827],
#  [1085.0, 4.366379310344827],
#  [1086.0, 4.366379310344827],
#  [1088.0, 4.366379310344827],
#  [1089.0, 5.0],
#  [1090.0, 4.0],
#  [1091.0, 4.366379310344827],
#  [1092.0, 5.0],
#  [1093.0, 4.366379310344827],
#  [1094.0, 4.366379310344827],
#  [1095.0, 4.366379310344827],
#  [1096.0, 4.366379310344827],
#  [1097.0, 5.0],
#  [1099.0, 4.366379310344827],
#  [1100.0, 4.366379310344827],
#  [1101.0, 4.366379310344827],
#  [1103.0, 4.366379310344827],
#  [1104.0, 4.366379310344827],
#  [1105.0, 4.366379310344827],
#  [1107.0, 4.366379310344827],
#  [1111.0, 4.366379310344827],
#  [1112.0, 4.366379310344827],
#  [1114.0, 4.366379310344827],
#  [1116.0, 4.366379310344827],
#  [1117.0, 4.366379310344827],
#  [1119.0, 4.366379310344827],
#  [1120.0, 4.366379310344827],
#  [1121.0, 4.366379310344827],
#  [1123.0, 4.366379310344827],
#  [1124.0, 4.366379310344827],
#  [1125.0, 4.366379310344827],
#  [1126.0, 4.366379310344827],
#  [1127.0, 4.0],
#  [1128.0, 4.366379310344827],
#  [1129.0, 4.366379310344827],
#  [1130.0, 4.366379310344827],
#  [1131.0, 4.366379310344827],
#  [1132.0, 4.366379310344827],
#  [1135.0, 4.366379310344827],
#  [1136.0, 5.0],
#  [1137.0, 4.366379310344827],
#  [1140.0, 4.366379310344827],
#  [1144.0, 4.366379310344827],
#  [1147.0, 4.366379310344827],
#  [1148.0, 4.366379310344827],
#  [1150.0, 4.366379310344827],
#  [1151.0, 4.366379310344827],
#  [1156.0, 4.366379310344827],
#  [1161.0, 4.366379310344827],
#  [1162.0, 4.366379310344827],
#  [1163.0, 4.366379310344827],
#  [1167.0, 4.366379310344827],
#  [1170.0, 4.366379310344827],
#  [1171.0, 4.366379310344827],
#  [1172.0, 4.366379310344827],
#  [1173.0, 4.366379310344827],
#  [1175.0, 4.366379310344827],
#  [1176.0, 4.366379310344827],
#  [1177.0, 4.366379310344827],
#  [1178.0, 4.366379310344827],
#  [1179.0, 4.366379310344827],
#  [1180.0, 4.366379310344827],
#  [1183.0, 4.366379310344827],
#  [1184.0, 4.366379310344827],
#  [1185.0, 4.366379310344827],
#  [1186.0, 4.366379310344827],
#  [1187.0, 4.366379310344827],
#  [1188.0, 4.366379310344827],
#  [1189.0, 4.366379310344827],
#  [1190.0, 4.366379310344827],
#  [1191.0, 4.366379310344827],
#  [1192.0, 4.366379310344827],
#  [1193.0, 4.366379310344827],
#  [1194.0, 4.366379310344827],
#  [1196.0, 5.0],
#  [1197.0, 5.0],
#  [1198.0, 5.0],
#  [1199.0, 4.366379310344827],
#  [1200.0, 4.366379310344827],
#  [1201.0, 4.366379310344827],
#  [1202.0, 4.366379310344827],
#  [1203.0, 4.366379310344827],
#  [1204.0, 4.366379310344827],
#  [1206.0, 5.0],
#  [1207.0, 4.366379310344827],
#  [1208.0, 4.0],
#  [1209.0, 4.366379310344827],
#  [1210.0, 5.0],
#  [1211.0, 4.366379310344827],
#  [1212.0, 4.366379310344827],
#  [1213.0, 5.0],
#  [1214.0, 4.0],
#  [1215.0, 4.366379310344827],
#  [1216.0, 4.366379310344827],
#  [1217.0, 4.366379310344827],
#  [1218.0, 4.366379310344827],
#  [1219.0, 2.0],
#  [1220.0, 5.0],
#  [1221.0, 4.366379310344827],
#  [1222.0, 5.0],
#  [1223.0, 4.366379310344827],
#  [1224.0, 5.0],
#  [1225.0, 4.366379310344827],
#  [1226.0, 5.0],
#  [1227.0, 4.366379310344827],
#  [1228.0, 4.366379310344827],
#  [1230.0, 4.366379310344827],
#  [1231.0, 4.366379310344827],
#  [1232.0, 4.366379310344827],
#  [1233.0, 4.366379310344827],
#  [1234.0, 4.366379310344827],
#  [1235.0, 4.366379310344827],
#  [1236.0, 4.366379310344827],
#  [1237.0, 4.366379310344827],
#  [1238.0, 4.366379310344827],
#  [1240.0, 5.0],
#  [1241.0, 4.366379310344827],
#  [1242.0, 4.366379310344827],
#  [1243.0, 4.366379310344827],
#  [1244.0, 4.366379310344827],
#  [1245.0, 4.366379310344827],
#  [1246.0, 4.366379310344827],
#  [1247.0, 4.366379310344827],
#  [1248.0, 4.366379310344827],
#  [1249.0, 4.366379310344827],
#  [1250.0, 4.366379310344827],
#  [1251.0, 4.366379310344827],
#  [1252.0, 4.366379310344827],
#  [1253.0, 4.366379310344827],
#  [1254.0, 4.366379310344827],
#  [1255.0, 4.366379310344827],
#  [1256.0, 5.0],
#  [1257.0, 4.366379310344827],
#  [1258.0, 3.0],
#  [1259.0, 4.366379310344827],
#  [1260.0, 4.366379310344827],
#  [1261.0, 4.366379310344827],
#  [1262.0, 4.366379310344827],
#  [1263.0, 4.366379310344827],
#  [1264.0, 4.366379310344827],
#  [1265.0, 4.0],
#  [1266.0, 4.366379310344827],
#  [1267.0, 4.366379310344827],
#  [1268.0, 4.366379310344827],
#  [1269.0, 4.366379310344827],
#  [1270.0, 5.0],
#  [1271.0, 4.366379310344827],
#  [1272.0, 4.366379310344827],
#  [1273.0, 4.366379310344827],
#  [1274.0, 4.366379310344827],
#  [1275.0, 5.0],
#  [1276.0, 4.366379310344827],
#  [1277.0, 4.366379310344827],
#  [1278.0, 5.0],
#  [1279.0, 4.366379310344827],
#  [1280.0, 4.366379310344827],
#  [1281.0, 4.366379310344827],
#  [1282.0, 5.0],
#  [1283.0, 4.366379310344827],
#  [1284.0, 4.366379310344827],
#  [1285.0, 4.366379310344827],
#  [1286.0, 4.366379310344827],
#  [1287.0, 4.366379310344827],
#  [1288.0, 4.366379310344827],
#  [1289.0, 4.366379310344827],
#  [1290.0, 4.366379310344827],
#  [1291.0, 5.0],
#  [1292.0, 4.366379310344827],
#  [1293.0, 4.366379310344827],
#  [1295.0, 4.366379310344827],
#  [1296.0, 4.366379310344827],
#  [1297.0, 4.366379310344827],
#  [1298.0, 5.0],
#  [1299.0, 4.366379310344827],
#  [1300.0, 4.366379310344827],
#  [1301.0, 4.366379310344827],
#  ...]

# %% [markdown]
# # Close the connection

# %%
conn.close()
# Out:
# 2025-10-25 19:40:21,872 INFO sqlalchemy.engine.Engine ROLLBACK
